# %% [markdown]
# <img src="https://i.imgur.com/FoKB5Z5.png" align="left" width="300" height="250" title="source: imgur.com" /></a>

# %% [markdown]
# ## Program Code: J620-002-4:2020
#
# ## Program Name: FRONT-END SOFTWARE DEVELOPMENT
#
# ## Title :  Exercise using BeautifulSoup and Selenium
#
# #### Name:
#
# #### IC Number:
#
# #### Date :
#
# #### Introduction :
#
#
#
# #### Conclusion :

# %% [markdown]
# # Exe09 - Exercise Using BeautifulSoup and Selenium on News Web Portal

# %% [markdown]
# Extract daily COVID-19 statistics from theStar
#
# Location: https://www.thestar.com.my/news/nation/2020/03/23/covid-19-current-situation-in-malaysia-updated-daily

# %%
import requests
from bs4 import BeautifulSoup

url='https://www.thestar.com.my/news/nation/2020/03/23/covid-19-current-situation-in-malaysia-updated-daily'

# get the webpage


# load webpage into bs4


# get data simply by looking for all <a> links
# Out:
# [<a class="navbar-brand brand-prime" data-content-id="https://www.thestar.com.my" data-content-title="The Star Online" data-content-type="Navigation" data-list-type="Header" href="/">
#  <svg aria-label="the star online" class="icon" height="55" role="img" width="164">
#  <image border="0" height="55" src="https://cdn.thestar.com.my/Themes/img/logo-tsol-logo.png" width="164" xlink:href="https://cdn.thestar.com.my/Themes/img/logo-tsol-full.svg"/>
#  </svg>
#  </a>,
#  <a class="btn--subscribe" data-content-id="https://www.thestar.com.my/subscription" data-content-title="Subscription" data-content-type="Navigation" data-list-type="Header" href="/subscription">Subscriptions</a>,
#  <a class="login" data-content-id="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=" data-content-title="Log In" data-content-type="Outbound Referral" data-list-type="Header" href="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=">
#                          Log In
#                       </a>,
#  <a class="log-in-light" id="hllogin"><i class="icon sprite-icon"></i></a>,
#  <a data-content-title="https://login.thestar.com.my/accountinfo/profile.aspx" data-content-type="Manage Profile" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/profile.aspx" target="_blank">Manage Profile
#                                  </a>,
#  <a data-content-title="https://login.thestar.com.my/accountinfo/changepassword.aspx" data-content-type="Change Password" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/changepassword.aspx" target="_blank">Change Password
#                                  </a>,
#  <a data-content-title="https://login.thestar.com.my/accountinfo/sessions.aspx" data-content-type="Manage Logins" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/sessions.aspx" target="_blank">Manage Logins
#                                  </a>,
#  <a data-content-title="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" data-content-type="Manage Subscription" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" target="_blank">Manage Subscription
#                                  </a>,
#  <a data-content-title="https://login.thestar.com.my/accountinfo/transhistory.aspx" data-content-type="Transaction History" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/transhistory.aspx" target="_blank">Transaction History
#                                  </a>,
#  <a data-content-title="https://login.thestar.com.my/accountinfo/billing.aspx" data-content-type="Manage Billing Info" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/billing.aspx" target="_blank">Manage Billing Info
#                                  </a>,
#  <a data-content-title="https://www.thestar.com.my/foryou/edit" data-content-type="Manage For You" data-list-type="Profile Management" href="https://www.thestar.com.my/foryou/edit">Manage For You
#                                  </a>,
#  <a data-content-title="https://www.thestar.com.my/saved-articles" data-content-type="Manage Bookmarks" data-list-type="Profile Management" href="https://www.thestar.com.my/saved-articles">Manage Bookmarks
#                                  </a>,
#  <a data-content-title="https://www.thestar.com.my/subscribe" data-content-type="Package &amp; Pricing" data-list-type="Profile Management" href="https://www.thestar.com.my/subscribe">Package &amp; Pricing
#                                  </a>,
#  <a data-content-title="https://www.thestar.com.my/faqs/" data-content-type="FAQs" data-list-type="Profile Management" href="https://www.thestar.com.my/faqs/">FAQs
#                                  </a>,
#  <a data-content-title="https://www.thestar.com.my" data-content-type="Log Out" data-list-type="Profile Management" href="#" onclick="logout();">Log Out
#                                  </a>,
#  <a class="navbar-brand brand-mobile left" data-content-id="https://www.thestar.com.my" data-content-title="The Star Online" data-content-type="Navigation" data-list-type="Header" href="/">
#  <svg aria-label="the star online" class="icon" height="26" role="img" width="70">
#  <image border="0" height="26" src="https://cdn.thestar.com.my/Themes/img/logo-tsol-mobile.png" width="70" xlink:href="https://cdn.thestar.com.my/Themes/img/logo-tsol-full.svg" xmlns:xlink="http://www.w3.org/1999/xlink"/>
#  </svg>
#  </a>,
#  <a class="home-light" data-content-id="https://www.thestar.com.my" data-content-title="Home" data-content-type="Navigation" data-list-type="Header" href="/" id="navi-home" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Home/' ); " target="">
#  <i class="icon sprite-icon"></i>
#  </a>,
#  <a class="starplus" data-content-id="https://www.thestar.com.my/starplus" data-content-title="StarPlus" data-content-type="Navigation" data-list-type="Header" href="/starplus" id="navi-starplus" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/StarPlus/' ); " target="">
#                      StarPlus
#                      </a>,
#  <a class="news" data-content-id="https://www.thestar.com.my/news" data-content-title="News" data-content-type="Navigation" data-list-type="Header" href="/news" id="navi-news" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/News/' ); " target="">
#                      News
#                      </a>,
#  <a class="asean+" data-content-id="https://www.thestar.com.my/aseanplus" data-content-title="Asean+" data-content-type="Navigation" data-list-type="Header" href="/aseanplus" id="navi-asean+" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/AseanPlus/' ); " target="">
#                      Asean+
#                      </a>,
#  <a class="business" data-content-id="https://www.thestar.com.my/business" data-content-title="Business" data-content-type="Navigation" data-list-type="Header" href="/business" id="navi-business" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Business/' ); " target="">
#                      Business
#                      </a>,
#  <a class="sport" data-content-id="https://www.thestar.com.my/sport" data-content-title="Sport" data-content-type="Navigation" data-list-type="Header" href="/sport" id="navi-sport" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Sport/' ); " target="">
#                      Sport
#                      </a>,
#  <a class="metro" data-content-id="https://www.thestar.com.my/metro" data-content-title="Metro" data-content-type="Navigation" data-list-type="Header" href="/metro" id="navi-metro" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Metro/' ); " target="">
#                      Metro
#                      </a>,
#  <a class="lifestyle" data-content-id="https://www.thestar.com.my/lifestyle" data-content-title="Lifestyle" data-content-type="Navigation" data-list-type="Header" href="/lifestyle" id="navi-lifestyle" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Lifestyle/' ); " target="">
#                      Lifestyle
#                      </a>,
#  <a class="food" data-content-id="https://www.thestar.com.my/food" data-content-title="Food" data-content-type="Navigation" data-list-type="Header" href="/food" id="navi-food" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Food/' ); " target="">
#                      Food
#                      </a>,
#  <a class="tech" data-content-id="https://www.thestar.com.my/tech" data-content-title="Tech" data-content-type="Navigation" data-list-type="Header" href="/tech" id="navi-tech" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Tech/' ); " target="">
#                      Tech
#                      </a>,
#  <a class="education" data-content-id="https://www.thestar.com.my/education" data-content-title="Education" data-content-type="Navigation" data-list-type="Header" href="/education" id="navi-education" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Education/' ); " target="">
#                      Education
#                      </a>,
#  <a class="opinion" data-content-id="https://www.thestar.com.my/opinion" data-content-title="Opinion" data-content-type="Navigation" data-list-type="Header" href="/opinion" id="navi-opinion" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Opinion/' ); " target="">
#                      Opinion
#                      </a>,
#  <a class="videos" data-content-id="https://www.thestartv.com/c/news" data-content-title="Videos" data-content-type="Outbound Referral" data-list-type="Header" href="https://www.thestartv.com/c/news" id="navi-videos" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , 'https://www.thestartv.com/c/news' ); " style="" target="_blank">
#                      Videos
#                      </a>,
#  <a class="photos" data-content-id="https://www.thestar.com.my/photos" data-content-title="Photos" data-content-type="Navigation" data-list-type="Header" href="/photos" id="navi-photos" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Photos/' ); " target="">
#                      Photos
#                      </a>,
#  <a class="starpicks" data-content-id="https://www.thestar.com.my/starpicks" data-content-title="StarPicks" data-content-type="Navigation" data-list-type="Header" href="/starpicks" id="navi-starpicks" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Starpicks/' ); " target="">
#                      StarPicks
#                      </a>,
#  <a aria-expanded="false" class="btn--subscribe dropdown-toggle" data-prokeyscachednode="false" onclick="toggleSubDrop()" role="button">Subscriptions</a>,
#  <a data-content-id="https://www.thestar.com.my/subscribe" data-content-title="The Star Digital Access" data-content-type="Navigation" data-list-type="Header" href="/subscribe">The Star Digital Access</a>,
#  <a data-content-id="https://newsstand.thestar.com.my/" data-content-title="Newsstand" data-content-type="Outbound Referral" data-list-type="Header" href="https://newsstand.thestar.com.my/">Newsstand</a>,
#  <a data-content-id="https://www.thestar.com.my/sms-services" data-content-title="SMS Services" data-content-type="Navigation" data-list-type="Header" href="/sms-services">SMS Services</a>,
#  <a class="login bttn bttn--log" data-content-id="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=" data-content-title="Log In" data-content-type="Outbound Referral" data-list-type="Header" href="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=">Log In
#                      </a>,
#  <a class="log-in" id="hllogin" onclick="toggleDrop()"><i class="icon sprite-icon"></i></a>,
#  <a data-content-title="https://login.thestar.com.my/accountinfo/profile.aspx" data-content-type="Manage Profile" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/profile.aspx" target="_blank">Manage Profile
#                              </a>,
#  <a data-content-title="https://login.thestar.com.my/accountinfo/changepassword.aspx" data-content-type="Change Password" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/changepassword.aspx" target="_blank">Change Password
#                              </a>,
#  <a data-content-title="https://login.thestar.com.my/accountinfo/sessions.aspx" data-content-type="Manage Logins" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/sessions.aspx" target="_blank">Manage Logins
#                              </a>,
#  <a data-content-title="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" data-content-type="Manage Subscription" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" target="_blank">Manage Subscription
#                              </a>,
#  <a data-content-title="https://login.thestar.com.my/accountinfo/transhistory.aspx" data-content-type="Transaction History" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/transhistory.aspx" target="_blank">Transaction History
#                              </a>,
#  <a data-content-title="https://login.thestar.com.my/accountinfo/billing.aspx" data-content-type="Manage Billing Info" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/billing.aspx" target="_blank">Manage Billing Info
#                              </a>,
#  <a data-content-title="https://www.thestar.com.my/foryou/edit" data-content-type="Manage For You" data-list-type="Profile Management" href="https://www.thestar.com.my/foryou/edit">Manage For You
#                              </a>,
#  <a data-content-title="https://www.thestar.com.my/saved-articles" data-content-type="Manage Bookmarks" data-list-type="Profile Management" href="https://www.thestar.com.my/saved-articles">Manage Bookmarks
#                              </a>,
#  <a data-content-title="https://www.thestar.com.my/subscribe" data-content-type="Package &amp; Pricing" data-list-type="Profile Management" href="https://www.thestar.com.my/subscribe">Package &amp; Pricing
#                              </a>,
#  <a data-content-title="https://www.thestar.com.my/faqs/" data-content-type="FAQs" data-list-type="Profile Management" href="https://www.thestar.com.my/faqs/">FAQs
#                              </a>,
#  <a data-content-title="https://www.thestar.com.my" data-content-type="Log Out" data-list-type="Profile Management" href="#" onclick="logout();">Log Out
#                              </a>,
#  <a class="btn btn-default adv-search-link" data-content-id="https://www.thestar.com.my/search/?adv=1" data-content-title="Advance Search" data-content-type="Navigation" data-list-type="Header" href="/search?adv=1" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Extra-Panel' , 'Advance Search' ); " onmousedown="searchAdvanceClick(this,'qTextBox2')" style="font-weight: 900"><i class="icon sprite-icon plus"></i>
#  </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my" data-content-title="Home" data-content-type="Navigation" data-list-type="Header" href="/" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/Home/');" target="_self">Home
#                      </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my/starplus" data-content-title="StarPlus" data-content-type="Navigation" data-list-type="Header" href="/starplus" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/StarPlus/');" target="">StarPlus
#                      </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my/news" data-content-title="News" data-content-type="Navigation" data-list-type="Header" href="/news" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/News/');" target="">News
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/news/latest" data-content-title="Latest" data-content-type="Navigation" data-list-type="Header" href="/news/latest" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/News/Latest/' ); " target="">Latest
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/news/nation" data-content-title="Nation" data-content-type="Navigation" data-list-type="Header" href="/news/nation" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/News/Nation/' ); " target="">Nation
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/news/world" data-content-title="World" data-content-type="Navigation" data-list-type="Header" href="/news/world" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/News/World/' ); " target="">World
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/news/environment" data-content-title="Environment" data-content-type="Navigation" data-list-type="Header" href="/news/environment" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/News/Environment/' ); " target="">Environment
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/news/in-other-media" data-content-title="In Other Media" data-content-type="Navigation" data-list-type="Header" href="/news/in-other-media" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/News/In-Other-Media/' ); " target="">In Other Media
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/news/true-or-not" data-content-title="True or Not" data-content-type="Navigation" data-list-type="Header" href="/news/true-or-not" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/News/True-Or-Not/' ); " target="">True or Not
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/news/focus" data-content-title="Focus" data-content-type="Navigation" data-list-type="Header" href="/news/focus" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/News/Focus/' ); " target="">Focus
#                              </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my/aseanplus" data-content-title="Asean+" data-content-type="Navigation" data-list-type="Header" href="/aseanplus" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/AseanPlus/');" target="">Asean+
#                      </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my/business" data-content-title="Business" data-content-type="Navigation" data-list-type="Header" href="/business" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/Business/');" target="">Business
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/business" data-content-title="News" data-content-type="Navigation" data-list-type="Header" href="/business" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/' ); " target="">News
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/business/smebiz" data-content-title="SMEBiz" data-content-type="Navigation" data-list-type="Header" href="/business/smebiz" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Smebiz/' ); " target="">SMEBiz
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/business/insight" data-content-title="Insight" data-content-type="Navigation" data-list-type="Header" href="/business/insight" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Insight/' ); " target="">Insight
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/business/unit-trust" data-content-title="Unit Trust" data-content-type="Navigation" data-list-type="Header" href="/business/unit-trust" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Unit-Trust/' ); " target="">Unit Trust
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/business/exchange-rates" data-content-title="Exchange Rates" data-content-type="Navigation" data-list-type="Header" href="/business/exchange-rates" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Exchange-Rates/' ); " target="">Exchange Rates
#                              </a>,
#  <a data-content-id="http://biz.thestar.com.my/portfolio/" data-content-title="My Portfolio" data-content-type="Outbound Referral" data-list-type="Header" href="http://biz.thestar.com.my/portfolio/" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , 'http://biz.thestar.com.my/portfolio/' ); " target="_blank">My Portfolio
#                              </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my/business/marketwatch" data-content-title="Market Watch" data-content-type="Navigation" data-list-type="Header" href="/business/marketwatch" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/Business/MarketWatch/');" target="">Market Watch
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/business/marketwatch" data-content-title="Bursa Overview" data-content-type="Navigation" data-list-type="Header" href="/business/marketwatch" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Marketwatch/' ); " target="">Bursa Overview
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/business/martketwatch/stock-list" data-content-title="Market Movers" data-content-type="Navigation" data-list-type="Header" href="/business/martketwatch/Stock-List" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Martketwatch/Stock-List/' ); " target="">Market Movers
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/business/martketwatch/financial-results" data-content-title="Financial Results" data-content-type="Navigation" data-list-type="Header" href="/business/martketwatch/Financial-Results" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Martketwatch/Financial-Results/' ); " target="">Financial Results
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/business/martketwatch/dividends" data-content-title="Dividends" data-content-type="Navigation" data-list-type="Header" href="/business/martketwatch/Dividends" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Martketwatch/Dividends/' ); " target="">Dividends
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/business/martketwatch/bonus" data-content-title="Bonus" data-content-type="Navigation" data-list-type="Header" href="/business/martketwatch/Bonus" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Martketwatch/Bonus/' ); " target="">Bonus
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/business/martketwatch/ipo" data-content-title="IPO" data-content-type="Navigation" data-list-type="Header" href="/business/martketwatch/IPO" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Martketwatch/IPO/' ); " target="">IPO
#                              </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my/sport" data-content-title="Sport" data-content-type="Navigation" data-list-type="Header" href="/sport" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/Sport/');" target="">Sport
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/football" data-content-title="Football" data-content-type="Navigation" data-list-type="Header" href="/sport/football" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Sport/Football/' ); " target="">Football
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/golf" data-content-title="Golf" data-content-type="Navigation" data-list-type="Header" href="/sport/golf" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Sport/Golf/' ); " target="">Golf
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/badminton" data-content-title="Badminton" data-content-type="Navigation" data-list-type="Header" href="/sport/badminton" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Sport/Badminton/' ); " target="">Badminton
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/tennis" data-content-title="Tennis" data-content-type="Navigation" data-list-type="Header" href="/sport/tennis" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Sport/Tennis/' ); " target="">Tennis
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/motorsport" data-content-title="Motorsport" data-content-type="Navigation" data-list-type="Header" href="/sport/motorsport" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Sport/Motorsport/' ); " target="">Motorsport
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/athletics" data-content-title="Athletics" data-content-type="Navigation" data-list-type="Header" href="/sport/athletics" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Sport/Athletics/' ); " target="">Athletics
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/hockey" data-content-title="Hockey" data-content-type="Navigation" data-list-type="Header" href="/sport/hockey" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Sport/Hockey/' ); " target="">Hockey
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/other-sport" data-content-title="Other Sport" data-content-type="Navigation" data-list-type="Header" href="/sport/other-sport" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Sport/Other-Sport/' ); " target="">Other Sport
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/say-what" data-content-title="Say What" data-content-type="Navigation" data-list-type="Header" href="/sport/say-what" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Sport/Say-What/' ); " target="">Say What
#                              </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my/metro" data-content-title="Metro" data-content-type="Navigation" data-list-type="Header" href="/metro" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/Metro/');" target="">Metro
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/metro/metro-news" data-content-title="Metro News" data-content-type="Navigation" data-list-type="Header" href="/metro/metro-news" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Metro/Metro-News/' ); " target="">Metro News
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/metro/community-sports" data-content-title="Community Sports" data-content-type="Navigation" data-list-type="Header" href="/metro/community-sports" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Metro/Community-Sports/' ); " target="">Community Sports
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/metro/views" data-content-title="Views" data-content-type="Navigation" data-list-type="Header" href="/metro/views" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Metro/Views/' ); " target="">Views
#                              </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my/lifestyle" data-content-title="Lifestyle" data-content-type="Navigation" data-list-type="Header" href="/lifestyle" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/Lifestyle/');" target="">Lifestyle
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/lifestyle/entertainment-and-style" data-content-title="Entertainment &amp;amp; Style" data-content-type="Navigation" data-list-type="Header" href="/lifestyle/entertainment-and-style" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Lifestyle/Entertainment-And-Style/' ); " target="">Entertainment &amp; Style
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/lifestyle/people-and-living" data-content-title="People &amp;amp; Living" data-content-type="Navigation" data-list-type="Header" href="/lifestyle/people-and-living" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Lifestyle/People-And-Living/' ); " target="">People &amp; Living
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/lifestyle/health-and-family" data-content-title="Health &amp;amp; Family" data-content-type="Navigation" data-list-type="Header" href="/lifestyle/health-and-family" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Lifestyle/Health-And-Family/' ); " target="">Health &amp; Family
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/lifestyle/travel-and-culture" data-content-title="Travel &amp;amp; Culture" data-content-type="Navigation" data-list-type="Header" href="/lifestyle/travel-and-culture" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Lifestyle/Travel-And-Culture/' ); " target="">Travel &amp; Culture
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/lifestyle/viewpoints" data-content-title="Viewpoints" data-content-type="Navigation" data-list-type="Header" href="/lifestyle/viewpoints" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Lifestyle/Viewpoints/' ); " target="">Viewpoints
#                              </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my/food" data-content-title="Food" data-content-type="Navigation" data-list-type="Header" href="/food" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/Food/');" target="">Food
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/food/food-news" data-content-title="Food News" data-content-type="Navigation" data-list-type="Header" href="/food/food-news" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Food/Food-News/' ); " target="">Food News
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/food/eating-out" data-content-title="Eating Out" data-content-type="Navigation" data-list-type="Header" href="/food/eating-out" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Food/Eating-Out/' ); " target="">Eating Out
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/food/food-for-thought" data-content-title="Food for Thought" data-content-type="Navigation" data-list-type="Header" href="/food/food-for-thought" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Food/Food-for-Thought/' ); " target="">Food for Thought
#                              </a>,
#  <a data-content-id="https://www.kuali.com/" data-content-title="Kuali" data-content-type="Outbound Referral" data-list-type="Header" href="https://www.kuali.com/" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , 'https://www.kuali.com/' ); " target="_blank">Kuali
#                              </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my/tech" data-content-title="Tech" data-content-type="Navigation" data-list-type="Header" href="/tech" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/Tech/');" target="">Tech
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/tech/tech-thoughts" data-content-title="Tech Thoughts" data-content-type="Navigation" data-list-type="Header" href="/tech/tech-thoughts" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Tech/Tech-Thoughts/' ); " target="">Tech Thoughts
#                              </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my/education" data-content-title="Education" data-content-type="Navigation" data-list-type="Header" href="/education" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/Education/');" target="">Education
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/education/news" data-content-title="News" data-content-type="Navigation" data-list-type="Header" href="/education/news" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Education/News/' ); " target="">News
#                              </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my/opinion" data-content-title="Opinion" data-content-type="Navigation" data-list-type="Header" href="/opinion" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/Opinion/');" target="">Opinion
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/opinion/letters" data-content-title="Letters" data-content-type="Navigation" data-list-type="Header" href="/opinion/letters" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Opinion/Letters/' ); " target="">Letters
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/opinion/columnists" data-content-title="Columnists" data-content-type="Navigation" data-list-type="Header" href="/opinion/columnists" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Opinion/Columnists/' ); " target="">Columnists
#                              </a>,
#  <a class="navigation-title" data-content-id="https://www.thestartv.com/c/news" data-content-title="Videos" data-content-type="Outbound Referral" data-list-type="Header" href="https://www.thestartv.com/c/news" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', 'https://www.thestartv.com/c/news');" target="_blank">Videos
#                      </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my/photos" data-content-title="Photos" data-content-type="Navigation" data-list-type="Header" href="/photos" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/Photos/');" target="">Photos
#                      </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my/starpicks" data-content-title="StarPicks" data-content-type="Navigation" data-list-type="Header" href="/starpicks" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/StarPicks/');" target="">StarPicks
#                      </a>,
#  <a class="navigation-title" data-content-id="https://www.thestar.com.my" data-content-title="More" data-content-type="Navigation" data-list-type="Header" href="#" id="mob_more" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/More/');" target="">More
#                      </a>,
#  <a data-content-id="https://thestarmall.com.my/collections/the-star?utm_source=tsol&amp;utm_medium=meganavi&amp;utm_campaign=general" data-content-title="The Star Mall" data-content-type="Outbound Referral" data-list-type="Header" href="https://thestarmall.com.my/collections/the-star?utm_source=tsol&amp;utm_medium=meganavi&amp;utm_campaign=general" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , 'https://thestarmall.com.my/collections/the-star?utm_source=TSOL&amp;utm_medium=MegaNavi&amp;utm_campaign=General' ); " target="_blank">The Star Mall
#                              </a>,
#  <a data-content-id="https://promocodes.thestar.com.my/" data-content-title="Vouchers" data-content-type="Outbound Referral" data-list-type="Header" href="https://promocodes.thestar.com.my/" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , 'https://promocodes.thestar.com.my/' ); " target="_blank">Vouchers
#                              </a>,
#  <a data-content-id="https://starsearch.thestar.com.my/" data-content-title="Classifieds" data-content-type="Outbound Referral" data-list-type="Header" href="https://starsearch.thestar.com.my/" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , 'https://starsearch.thestar.com.my/' ); " target="_blank">Classifieds
#                              </a>,
#  <a data-content-id="http://events.thestar.com.my/" data-content-title="Events" data-content-type="Outbound Referral" data-list-type="Header" href="http://events.thestar.com.my/" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , 'http://events.thestar.com.my/' ); " target="_blank">Events
#                              </a>,
#  <a data-content-id="http://www.starcherish.com/" data-content-title="StarCherish.com" data-content-type="Outbound Referral" data-list-type="Header" href="http://www.starcherish.com/" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , 'http://www.starcherish.com/' ); " target="_blank">StarCherish.com
#                              </a>,
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my" data-content-title="Home" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/" onclick="ga('send', 'event', 'TSOL MEGA NAVI', 'Standard', '/Home/');" target="_self">Home
#                                  </a>,
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/starplus" data-content-title="StarPlus" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/starplus" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/StarPlus/' ); " target="">
#                                  StarPlus
#                              </a>,
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/news" data-content-title="News" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/' ); " target="">
#                                  News
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/news/latest" data-content-title="Latest" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news/latest" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/Latest/' ); " target="">Latest
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/news/nation" data-content-title="Nation" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news/nation" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/Nation/' ); " target="">Nation
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/news/world" data-content-title="World" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news/world" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/World/' ); " target="">World
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/news/environment" data-content-title="Environment" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news/environment" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/Environment/' ); " target="">Environment
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/news/in-other-media" data-content-title="In Other Media" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news/in-other-media" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/In-Other-Media/' ); " target="">In Other Media
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/news/true-or-not" data-content-title="True or Not" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news/true-or-not" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/True-Or-Not/' ); " target="">True or Not
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/news/focus" data-content-title="Focus" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news/focus" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/Focus/' ); " target="">Focus
#                                      </a>,
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/aseanplus" data-content-title="Asean+" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/aseanplus" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/AseanPlus/' ); " target="">
#                                  Asean+
#                              </a>,
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/business" data-content-title="Business" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/' ); " target="">
#                                  Business
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/business" data-content-title="News" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/' ); " target="">News
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/business/smebiz" data-content-title="SMEBiz" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/smebiz" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Smebiz/' ); " target="">SMEBiz
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/business/insight" data-content-title="Insight" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/insight" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Insight/' ); " target="">Insight
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/business/unit-trust" data-content-title="Unit Trust" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/unit-trust" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Unit-Trust/' ); " target="">Unit Trust
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/business/exchange-rates" data-content-title="Exchange Rates" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/exchange-rates" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Exchange-Rates/' ); " target="">Exchange Rates
#                                      </a>,
#  <a data-content-id="http://biz.thestar.com.my/portfolio/" data-content-title="My Portfolio" data-content-type="Outbound Referral" data-list-type="Header Mega Menu" href="http://biz.thestar.com.my/portfolio/" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , 'http://biz.thestar.com.my/portfolio/' ); " target="_blank">My Portfolio
#                                      </a>,
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/business/marketwatch" data-content-title="Market Watch" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/marketwatch" onclick="ga('send', 'event', 'TSOL MEGA NAVI', 'Standard', '/Business/MarketWatch/');" target="">
#                                  Market Watch
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/business/marketwatch" data-content-title="Bursa Overview" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/marketwatch" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Marketwatch/' ); " target="">Bursa Overview
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/business/martketwatch/stock-list" data-content-title="Market Movers" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/martketwatch/Stock-List" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Martketwatch/Stock-List/' ); " target="">Market Movers
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/business/martketwatch/financial-results" data-content-title="Financial Results" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/martketwatch/Financial-Results" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Martketwatch/Financial-Results/' ); " target="">Financial Results
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/business/martketwatch/dividends" data-content-title="Dividends" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/martketwatch/Dividends" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Martketwatch/Dividends/' ); " target="">Dividends
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/business/martketwatch/bonus" data-content-title="Bonus" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/martketwatch/Bonus" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Martketwatch/Bonus/' ); " target="">Bonus
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/business/martketwatch/ipo" data-content-title="IPO" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/martketwatch/IPO" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Martketwatch/IPO/' ); " target="">IPO
#                                      </a>,
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/sport" data-content-title="Sport" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/' ); " target="">
#                                  Sport
#                              </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/football" data-content-title="Football" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/football" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Football/' ); " target="">Football
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/golf" data-content-title="Golf" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/golf" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Golf/' ); " target="">Golf
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/badminton" data-content-title="Badminton" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/badminton" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Badminton/' ); " target="">Badminton
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/tennis" data-content-title="Tennis" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/tennis" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Tennis/' ); " target="">Tennis
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/motorsport" data-content-title="Motorsport" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/motorsport" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Motorsport/' ); " target="">Motorsport
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/athletics" data-content-title="Athletics" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/athletics" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Athletics/' ); " target="">Athletics
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/hockey" data-content-title="Hockey" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/hockey" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Hockey/' ); " target="">Hockey
#                                      </a>,
#  <a data-content-id="https://www.thestar.com.my/sport/other-sport" data-content-title="Other Sports" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/other-sport" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Other-Sport/' ); " target="">Other Sports
#                                      </a>,
# ...
#                          Armed Forces arrest 45 illegal immigrants off Mersing
#                      </a>,
#  <a class="slider-story__image" href="https://www.thestar.com.my/news/nation/2021/11/15/kedah039s-decision-on-gaming-outlets-goes-against-malaysia039s-pluralism-says-mca" target="">
#  <div class="slider-story__image-container">
#  <script type="text/javascript"> GenerateMediaTag({"cms_image_id":479553,"np_image_id":1368783,"image_caption":"","np_related_article_id":683591,"cms_type":"live","image_description":"","image_path":"uploads\/images\/2021\/11\/15\/1368783.jpg","media_type":0,"is_old_image":0,"small_image":"","is_updated":0,"image_cropping":"{\"original_image\":{\"image_original_width\":640,\"image_original_height\":400,\"icd_image_type\":\"original_image\"}}","media_order":0,"is_copied":0,"image_is_deleted":0,"image_alt_text":""},true, false, '','small'); </script>
#  </div>
#  </a>,
#  <a class="slider-story__title" href="https://www.thestar.com.my/news/nation/2021/11/15/kedah039s-decision-on-gaming-outlets-goes-against-malaysia039s-pluralism-says-mca" target="">
#                          Kedah's decision on gaming outlets goes against Malaysia's pluralism, says MCA
#                      </a>,
#  <a class="slider-story__image" href="https://www.thestar.com.my/news/nation/2021/11/15/geramm-irked-by-hostile-remarks-reportedly-aimed-at-journalist-by-pas-duo" target="">
#  <div class="slider-story__image-container">
#  <script type="text/javascript"> GenerateMediaTag({"image_path":"https://cdn.thestar.com.my/Themes/img/tsol-default-image2017.png","media_type":"0"},true, false, '','small'); </script>
#  </div>
#  </a>,
#  <a class="slider-story__title" href="https://www.thestar.com.my/news/nation/2021/11/15/geramm-irked-by-hostile-remarks-reportedly-aimed-at-journalist-by-pas-duo" target="">
#                          Geramm irked by hostile remarks reportedly aimed at journalist by PAS duo
#                      </a>,
#  <a class="slider-story__image" href="https://www.thestar.com.my/news/nation/2021/11/15/criminal-court-has-no-jurisdiction-to-nullify-rosmah039s-corruption-trial-says-prosecution" target="">
#  <div class="slider-story__image-container">
#  <script type="text/javascript"> GenerateMediaTag({"cms_image_id":479545,"np_image_id":1368749,"image_caption":"","np_related_article_id":683578,"cms_type":"live","image_description":"","image_path":"uploads\/images\/2021\/11\/15\/1368749.jpg","media_type":0,"is_old_image":0,"small_image":"","is_updated":0,"image_cropping":"{\"original_image\":{\"image_original_width\":1240,\"image_original_height\":826,\"icd_image_type\":\"original_image\"}}","media_order":0,"is_copied":0,"image_is_deleted":0,"image_alt_text":""},true, false, '','small'); </script>
#  </div>
#  </a>,
#  <a class="slider-story__title" href="https://www.thestar.com.my/news/nation/2021/11/15/criminal-court-has-no-jurisdiction-to-nullify-rosmah039s-corruption-trial-says-prosecution" target="">
#                          Criminal court has no jurisdiction to nullify Rosmah's corruption trial, says prosecution
#                      </a>,
#  <a class="slider-story__image" href="https://www.thestar.com.my/news/nation/2021/11/15/1mdb-trial-najib-jho-low-had-039very-close039-relationship-court-told" target="">
#  <div class="slider-story__image-container">
#  <script type="text/javascript"> GenerateMediaTag({"cms_image_id":479543,"np_image_id":1368727,"image_caption":"","np_related_article_id":683568,"cms_type":"live","image_description":"","image_path":"uploads\/images\/2021\/11\/15\/1368727.jpg","media_type":0,"is_old_image":0,"small_image":"","is_updated":0,"image_cropping":"{\"original_image\":{\"image_original_width\":null,\"image_original_height\":null,\"icd_image_type\":\"original_image\"}}","media_order":0,"is_copied":0,"image_is_deleted":0,"image_alt_text":""},true, false, '','small'); </script>
#  </div>
#  </a>,
#  <a class="slider-story__title" href="https://www.thestar.com.my/news/nation/2021/11/15/1mdb-trial-najib-jho-low-had-039very-close039-relationship-court-told" target="">
#                          1MDB trial: Najib, Jho Low had 'very close' relationship, court told
#                      </a>,
#  <a class="slider-story__image" href="https://www.thestar.com.my/news/nation/2021/11/15/bike-e-hailing-services-put-on-hold-due-to-safety-reasons-says-deputy-transport-minister" target="">
#  <div class="slider-story__image-container">
#  <script type="text/javascript"> GenerateMediaTag({"cms_image_id":479541,"np_image_id":1368719,"image_caption":"","np_related_article_id":683556,"cms_type":"live","image_description":"","image_path":"uploads\/images\/2021\/11\/15\/1368719.jpg","media_type":0,"is_old_image":0,"small_image":"","is_updated":0,"image_cropping":"{\"original_image\":{\"image_original_width\":1240,\"image_original_height\":861,\"icd_image_type\":\"original_image\"}}","media_order":0,"is_copied":0,"image_is_deleted":0,"image_alt_text":""},true, false, '','small'); </script>
#  </div>
#  </a>,
#  <a class="slider-story__title" href="https://www.thestar.com.my/news/nation/2021/11/15/bike-e-hailing-services-put-on-hold-due-to-safety-reasons-says-deputy-transport-minister" target="">
#                          Bike e-hailing services put on hold due to safety reasons, says Deputy Transport Minister
#                      </a>,
#  <a class="slider-story__image" href="https://www.thestar.com.my/news/nation/2021/11/15/global-energy-crisis-not-affecting-m039sia039s-energy-supply-security-says-ali-biju" target="">
#  <div class="slider-story__image-container">
#  <script type="text/javascript"> GenerateMediaTag({"cms_image_id":479520,"np_image_id":1368649,"image_caption":"","np_related_article_id":683523,"cms_type":"live","image_description":"","image_path":"uploads\/images\/2021\/11\/15\/1368649.jpg","media_type":0,"is_old_image":0,"small_image":"","is_updated":0,"image_cropping":"{\"original_image\":{\"image_original_width\":null,\"image_original_height\":null,\"icd_image_type\":\"original_image\"}}","media_order":0,"is_copied":0,"image_is_deleted":0,"image_alt_text":""},true, false, '','small'); </script>
#  </div>
#  </a>,
#  <a class="slider-story__title" href="https://www.thestar.com.my/news/nation/2021/11/15/global-energy-crisis-not-affecting-m039sia039s-energy-supply-security-says-ali-biju" target="">
#                          Global energy crisis not affecting M'sia's energy supply security, says Ali Biju
#                      </a>,
#  <a class="slider-story__image" href="https://www.thestar.com.my/news/nation/2021/11/15/nagaenthran039s-sister-pleads-with-singapore-to-give-brother-a-second-chance" target="">
#  <div class="slider-story__image-container">
#  <script type="text/javascript"> GenerateMediaTag({"cms_image_id":479518,"np_image_id":1368643,"image_caption":"","np_related_article_id":683517,"cms_type":"live","image_description":"","image_path":"uploads\/images\/2021\/11\/15\/1368643.jpeg","media_type":0,"is_old_image":0,"small_image":"","is_updated":0,"image_cropping":"{\"original_image\":{\"image_original_width\":960,\"image_original_height\":639,\"icd_image_type\":\"original_image\"}}","media_order":0,"is_copied":0,"image_is_deleted":0,"image_alt_text":""},true, false, '','small'); </script>
#  </div>
#  </a>,
#  <a class="slider-story__title" href="https://www.thestar.com.my/news/nation/2021/11/15/nagaenthran039s-sister-pleads-with-singapore-to-give-brother-a-second-chance" target="">
#                          Nagaenthran's sister pleads with Singapore to give brother a second chance
#                      </a>,
#  <a id="loadMorestories">Load more </a>,
#  <a data-content-title="#" data-content-type="View More" data-list-type="Vouchers Widget" data-list-variant="#" href="#" id="ViewMoreVoucher" target="_blank">View More Vouchers</a>,
#  <a data-content-id="https://www.thestar.com.my/subscribe" data-content-title="The Star Digital Access" data-content-type="Navigation" data-list-type="Footer" href="https://www.thestar.com.my/subscribe" id="tsolFooter_home_sitemap_hyperlink" target="_blank">The Star Digital Access
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/sms-services" data-content-title="SMS Services" data-content-type="Navigation" data-list-type="Footer" href="/SMS-Services" id="tsolFooter_home_sitemap_hyperlink" target="">SMS Services
#                      </a>,
#  <a data-content-id="https://newsstand.thestar.com.my/" data-content-title="Newsstand" data-content-type="Outbound Referral" data-list-type="Footer" href="https://newsstand.thestar.com.my/" id="tsolFooter_home_sitemap_hyperlink" target="_blank">Newsstand
#                      </a>,
#  <a data-content-id="https://bookstore.thestar.com.my/" data-content-title="Other Publications" data-content-type="Outbound Referral" data-list-type="Footer" href="https://bookstore.thestar.com.my/" id="tsolFooter_home_sitemap_hyperlink" target="_blank">Other Publications
#                      </a>,
#  <a data-content-id="http://advertising.thestar.com.my/" data-content-title="Our Rate Card" data-content-type="Outbound Referral" data-list-type="Footer" href="http://advertising.thestar.com.my/" id="tsolFooter_home_sitemap_hyperlink" target="_blank">Our Rate Card
#                      </a>,
#  <a data-content-id="https://starsearch.thestar.com.my/" data-content-title="Classifieds" data-content-type="Outbound Referral" data-list-type="Footer" href="https://starsearch.thestar.com.my/" id="tsolFooter_home_sitemap_hyperlink" target="_blank">Classifieds
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/aboutus" data-content-title="About Us" data-content-type="Navigation" data-list-type="Footer" href="/AboutUs" id="tsolFooter_home_sitemap_hyperlink" target="">About Us
#                      </a>,
#  <a data-content-id="http://starmediagroup.my/careers/life-with-us/" data-content-title="Job Opportunities" data-content-type="Outbound Referral" data-list-type="Footer" href="http://starmediagroup.my/careers/life-with-us/" id="tsolFooter_home_sitemap_hyperlink" target="_blank">Job Opportunities
#                      </a>,
#  <a data-content-id="https://www.starmediagroup.my/" data-content-title="Investor Relations" data-content-type="Outbound Referral" data-list-type="Footer" href="https://www.starmediagroup.my/" id="tsolFooter_home_sitemap_hyperlink" target="_blank">Investor Relations
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/contactus" data-content-title="Contact Us" data-content-type="Navigation" data-list-type="Footer" href="/ContactUs" id="tsolFooter_home_sitemap_hyperlink" target="">Contact Us
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/faqs" data-content-title="FAQs" data-content-type="Navigation" data-list-type="Footer" href="/FAQs" id="tsolFooter_home_sitemap_hyperlink" target="">FAQs
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/privacy" data-content-title="Privacy Statement" data-content-type="Navigation" data-list-type="Footer" href="/Privacy" id="tsolFooter_home_sitemap_hyperlink" target="">Privacy Statement
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/terms" data-content-title="Terms &amp;amp; Conditions" data-content-type="Navigation" data-list-type="Footer" href="/Terms" id="tsolFooter_home_sitemap_hyperlink" target="">Terms &amp; Conditions
#                      </a>,
#  <a class="youtube" data-content-id="https://www.youtube.com/user/thestaronline" data-content-title="Youtube" data-content-type="Social Page" data-list-type="Footer" href="https://www.youtube.com/user/thestaronline" target="_blank">
#  <i class="icon sprite-icon"></i>
#  </a>,
#  <a class="instagram-white" data-content-id="https://www.instagram.com/thestaronline/?hl=en" data-content-title="Instagram" data-content-type="Social Page" data-list-type="Footer" href="https://www.instagram.com/thestaronline/?hl=en" target="_blank">
#  <i class="icon sprite-icon"></i>
#  </a>,
#  <a class="twitter-white" data-content-id="http://twitter.com/staronline" data-content-title="Twitter" data-content-type="Social Page" data-list-type="Footer" href="http://twitter.com/staronline" target="_blank">
#  <i class="icon sprite-icon"></i>
#  </a>,
#  <a class="facebook-white" data-content-id="http://www.facebook.com/TheStarOnline" data-content-title="Facebook" data-content-type="Social Page" data-list-type="Footer" href="http://www.facebook.com/TheStarOnline" target="_blank">
#  <i class="icon sprite-icon"></i>
#  </a>,
#  <a class="telegram" data-content-id="https://t.me/thestar_official" data-content-title="telegram" data-content-type="Social Page" data-list-type="Footer" href="https://t.me/thestar_official" target="_blank">
#  <i class="icon sprite-icon"></i>
#  </a>,
#  <a class="playstore-large" data-content-id="https://play.google.com/store/apps/details?id=com.knx.thestarmobile" data-content-title="Google Play" data-content-type="App Download" data-list-type="Footer" href="https://play.google.com/store/apps/details?id=com.knx.thestarmobile" target="_blank"><i class="icon sprite-icon"></i>
#  </a>,
#  <a class="appstore-large" data-content-id="https://itunes.apple.com/app/the-star-mobile/id428184176?mt=8" data-content-title="App Store" data-content-type="App Download" data-list-type="Footer" href="https://itunes.apple.com/app/the-star-mobile/id428184176?mt=8" target="_blank"><i class="icon sprite-icon"></i>
#  </a>,
#  <a class="huawei" data-content-id="http://cdc.hispace.hicloud.com/000000WJ" data-content-title="APPGALLERY" data-content-type="App Download" data-list-type="Footer" href="http://cdc.hispace.hicloud.com/000000WJ" target="_blank">
#  <i class="icon sprite-icon"></i>
#  </a>,
#  <a data-content-id="https://www.thestar.com.my" data-content-title="Home" data-content-type="Navigation" data-list-type="Bottom Sticky Menu" href="/" onclick="ga('send', 'event', 'TSOL STICKY NAVI', 'Standard', '/Home/');">
#  <div class="mobilenav__icon home"></div>
#                          Home
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/foryou" data-content-title="For You" data-content-type="Navigation" data-list-type="Bottom Sticky Menu" href="/foryou" onclick="ga('send', 'event', 'TSOL STICKY NAVI', 'Standard', '/For You/');">
#  <div class="mobilenav__icon paper"></div>
#                          For You
#                      </a>,
#  <a data-content-id="https://www.thestar.com.my/saved-articles" data-content-title="Bookmark" data-content-type="Navigation" data-list-type="Bottom Sticky Menu" href="/saved-articles" onclick="ga('send', 'event', 'TSOL STICKY NAVI', 'Standard', '/Saved-Articles/');">
#  <div class="mobilenav__icon bookmark"></div>
#                          Bookmark
#                      </a>,
#  <a class="btn btn-default adv-search-link" data-content-id="https://www.thestar.com.my/search/?adv=1" data-content-title="Advance Search" data-content-type="Navigation" data-list-type="Header" href="/search?adv=1" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Extra-Panel' , 'Advance Search' ); " onmousedown="searchAdvanceClick(this,'qTextBox')" style="font-weight: 900"><i class="icon sprite-icon plus"></i>
#  </a>,
#  <a class="close"><i aria-hidden="true" class="fa fa-times"></i></a>,
#  <a class="f14" tmp:href="https://www.thestar.com.my/subscribe" tmp:id="{{cX.CCE.clickTracker(item)}}">
#  <p style="text-align:center;">{{item['V1 Header']}}
#     {{item['V1 Body']}}
#   <!--% if (item.campaign != 17 && item.campaign != 19) { %-->
#    {{item['V2 Header']}}
#  <!--% } %-->
#  </p></a>,
#  <a class="close" id="widgetBoxCloseButton"><img src="https://cdn.thestar.com.my/Themes/img/times-solid.png" style="width: 12px; height:12px;"/></a>,
#  <a class="widget-link" id="widget-link">Download now!</a>,
#  <a id="widget-skip">Skip</a>,
#  <a href="https://www.thestar.com.my/privacy/" target="_blank">Privacy Policy</a>,
#  <a href="https://www.thestar.com.my/terms/" target="_blank">Terms and Conditions</a>,
#  <a class="widget-link2" id="widget-link2">downloading</a>]

# %%
import requests
from bs4 import BeautifulSoup

url='https://www.thestar.com.my/news/nation/2020/03/23/covid-19-current-situation-in-malaysia-updated-daily'

# get the webpage


# load webpage into bs4


# get data simply by looking for all <a> links
# Out:
# ['\n\n\n\n',
#  'Subscriptions',
#  '\n                        Log In\n                     ',
#  '',
#  'Manage Profile\n                                ',
#  'Change Password\n                                ',
#  'Manage Logins\n                                ',
#  'Manage Subscription\n                                ',
#  'Transaction History\n                                ',
#  'Manage Billing Info\n                                ',
#  'Manage For You\n                                ',
#  'Manage Bookmarks\n                                ',
#  'Package & Pricing\n                                ',
#  'FAQs\n                                ',
#  'Log Out\n                                ',
#  '\n\n\n\n',
#  '\n\n',
#  '\n                    StarPlus\n                    ',
#  '\n                    News\n                    ',
#  '\n                    Asean+\n                    ',
#  '\n                    Business\n                    ',
#  '\n                    Sport\n                    ',
#  '\n                    Metro\n                    ',
#  '\n                    Lifestyle\n                    ',
#  '\n                    Food\n                    ',
#  '\n                    Tech\n                    ',
#  '\n                    Education\n                    ',
#  '\n                    Opinion\n                    ',
#  '\n                    Videos\n                    ',
#  '\n                    Photos\n                    ',
#  '\n                    StarPicks\n                    ',
#  'Subscriptions',
#  'The Star Digital Access',
#  'Newsstand',
#  'SMS Services',
#  'Log In\n                    ',
#  '',
#  'Manage Profile\n                            ',
#  'Change Password\n                            ',
#  'Manage Logins\n                            ',
#  'Manage Subscription\n                            ',
#  'Transaction History\n                            ',
#  'Manage Billing Info\n                            ',
#  'Manage For You\n                            ',
#  'Manage Bookmarks\n                            ',
#  'Package & Pricing\n                            ',
#  'FAQs\n                            ',
#  'Log Out\n                            ',
#  '\n',
#  'Home\n                    ',
#  'StarPlus\n                    ',
#  'News\n                    ',
#  'Latest\n                            ',
#  'Nation\n                            ',
#  'World\n                            ',
#  'Environment\n                            ',
#  'In Other Media\n                            ',
#  'True or Not\n                            ',
#  'Focus\n                            ',
#  'Asean+\n                    ',
#  'Business\n                    ',
#  'News\n                            ',
#  'SMEBiz\n                            ',
#  'Insight\n                            ',
#  'Unit Trust\n                            ',
#  'Exchange Rates\n                            ',
#  'My Portfolio\n                            ',
#  'Market Watch\n                    ',
#  'Bursa Overview\n                            ',
#  'Market Movers\n                            ',
#  'Financial Results\n                            ',
#  'Dividends\n                            ',
#  'Bonus\n                            ',
#  'IPO\n                            ',
#  'Sport\n                    ',
#  'Football\n                            ',
#  'Golf\n                            ',
#  'Badminton\n                            ',
#  'Tennis\n                            ',
#  'Motorsport\n                            ',
#  'Athletics\n                            ',
#  'Hockey\n                            ',
#  'Other Sport\n                            ',
#  'Say What\n                            ',
#  'Metro\n                    ',
#  'Metro News\n                            ',
#  'Community Sports\n                            ',
#  'Views\n                            ',
#  'Lifestyle\n                    ',
#  'Entertainment & Style\n                            ',
#  'People & Living\n                            ',
#  'Health & Family\n                            ',
#  'Travel & Culture\n                            ',
#  'Viewpoints\n                            ',
#  'Food\n                    ',
#  'Food News\n                            ',
#  'Eating Out\n                            ',
#  'Food for Thought\n                            ',
#  'Kuali\n                            ',
#  'Tech\n                    ',
#  'Tech Thoughts\n                            ',
#  'Education\n                    ',
#  'News\n                            ',
#  'Opinion\n                    ',
#  'Letters\n                            ',
#  'Columnists\n                            ',
#  'Videos\n                    ',
#  'Photos\n                    ',
#  'StarPicks\n                    ',
#  'More\n                    ',
#  'The Star Mall\n                            ',
#  'Vouchers\n                            ',
#  'Classifieds\n                            ',
#  'Events\n                            ',
#  'StarCherish.com\n                            ',
#  'Home\n                                ',
#  '\n                                StarPlus\n                            ',
#  '\n                                News\n                            ',
#  'Latest\n                                    ',
#  'Nation\n                                    ',
#  'World\n                                    ',
#  'Environment\n                                    ',
#  'In Other Media\n                                    ',
#  'True or Not\n                                    ',
#  'Focus\n                                    ',
#  '\n                                Asean+\n                            ',
#  '\n                                Business\n                            ',
#  'News\n                                    ',
#  'SMEBiz\n                                    ',
#  'Insight\n                                    ',
#  'Unit Trust\n                                    ',
#  'Exchange Rates\n                                    ',
#  'My Portfolio\n                                    ',
#  '\n                                Market Watch\n                            ',
#  'Bursa Overview\n                                    ',
#  'Market Movers\n                                    ',
#  'Financial Results\n                                    ',
#  'Dividends\n                                    ',
#  'Bonus\n                                    ',
#  'IPO\n                                    ',
#  '\n                                Sport\n                            ',
#  'Football\n                                    ',
#  'Golf\n                                    ',
#  'Badminton\n                                    ',
#  'Tennis\n                                    ',
#  'Motorsport\n                                    ',
#  'Athletics\n                                    ',
#  'Hockey\n                                    ',
#  'Other Sports\n                                    ',
#  'Say What\n                                    ',
#  '\n                                Metro\n                            ',
#  'Metro News\n                                    ',
#  'Community Sports\n                                    ',
#  'Views\n                                    ',
#  '\n                                Lifestyle\n                            ',
#  'Entertainment & Style\n                                    ',
#  'People & Living\n                                    ',
#  'Health & Family\n                                    ',
#  'Travel & Culture\n                                    ',
#  'Viewpoints\n                                    ',
#  '\n                                Food\n                            ',
#  'Food News\n                                    ',
#  'Eating Out\n                                    ',
#  'Food for Thought\n                                    ',
#  'Kuali\n                                    ',
#  '\n                                Tech\n                            ',
#  'Tech Thoughts\n                                    ',
#  '\n                                Education\n                            ',
#  'News\n                                    ',
#  '\n                                Opinion\n                            ',
#  'Columnists\n                                    ',
#  'Letters\n                                    ',
#  '\n                                Videos\n                            ',
#  '\n                                Photos\n                            ',
#  '\n                                StarPicks\n                            ',
#  '\n                                More\n                            ',
#  'The Star Mall\n                                    ',
#  'Vouchers\n                                    ',
#  'Classifieds\n                                    ',
#  'Events\n                                    ',
#  'StarCherish.com\n                                    ',
#  'DIYANA PFORDTEN',
#  'RAZAK AHMAD',
#  'Nation\n                        ',
#  '\n\n',
#  'Nation',
#  'Covid-19: New daily infections drop to 5,143 cases on Monday (Nov 15), says Health DG',
#  'Nation',
#  "Covid-19: 95.2% of M'sia's adult population fully vaxxed as of Sunday (Nov 14)",
#  'Indonesia',
#  'Indonesia reports 339 newly-confirmed Covid-19 cases, 15 more deaths on Sunday (Nov 14)',
#  'here',
#  'Interactive: How Malaysia and other countries are easing their Covid-19 restrictions',
#  'Interactive: Malaysia’s Covid-19 fight boosted as green zones more than double.',
#  'INTERACTIVE: In the Covid-19 era of virtual meetings, physical sittings still the norm for many parliaments worldwide',
#  'Telegram ',
#  'Covid-19 Coronavirus',
#  'Malaysia',
#  'Movement Control Order',
#  'Wuhan',
#  'Coronavirus',
#  'China',
#  'Quarantine',
#  'Outbreak',
#  'Disease',
#  '2019-nCoV',
#  'Covid-19',
#  'Found a mistake in this article?',
#  '\n\n',
#  'Nation',
#  'Covid-19: New daily infections drop to 5,143 cases on Monday (Nov 15), says Health DG',
#  '\n\n',
#  'Nation',
#  "Covid-19: 95.2% of M'sia's adult population fully vaxxed as of Sunday (Nov 14)",
#  '\n\n',
#  'Indonesia',
#  'Indonesia reports 339 newly-confirmed Covid-19 cases, 15 more deaths on Sunday (Nov 14)',
#  '\n\n',
#  'Nation',
#  'Covid-19: New daily infections drop to 5,143 cases on Monday (Nov 15), says Health DG',
#  '\n\n',
#  'Nation',
#  "Covid-19: 95.2% of M'sia's adult population fully vaxxed as of Sunday (Nov 14)",
#  '\n\n',
#  'Indonesia',
#  'Indonesia reports 339 newly-confirmed Covid-19 cases, 15 more deaths on Sunday (Nov 14)',
#  '\n\n\n\n',
#  '\n                        IOJ chides PAS leaders for allegedly intimidating reporter\n                    ',
#  '\n\n\n\n',
#  '\n                        Education Ministry: 2022/2023 school academic calendar to begin on March 21\n                    ',
#  '\n\n\n\n',
#  '\n                        Armed Forces arrest 45 illegal immigrants off Mersing\n                    ',
#  '\n\n\n\n',
#  "\n                        Kedah's decision on gaming outlets goes against Malaysia's pluralism, says MCA\n                    ",
#  '\n\n\n\n',
#  '\n                        Geramm irked by hostile remarks reportedly aimed at journalist by PAS duo\n                    ',
#  '\n\n\n\n',
#  "\n                        Criminal court has no jurisdiction to nullify Rosmah's corruption trial, says prosecution\n                    ",
#  '\n\n\n\n',
#  "\n                        1MDB trial: Najib, Jho Low had 'very close' relationship, court told\n                    ",
#  '\n\n\n\n',
#  '\n                        Bike e-hailing services put on hold due to safety reasons, says Deputy Transport Minister\n                    ',
#  '\n\n\n\n',
#  "\n                        Global energy crisis not affecting M'sia's energy supply security, says Ali Biju\n                    ",
#  '\n\n\n\n',
#  "\n                        Nagaenthran's sister pleads with Singapore to give brother a second chance\n                    ",
#  'Load more ',
#  'View More Vouchers',
#  'The Star Digital Access\n                    ',
#  'SMS Services\n                    ',
#  'Newsstand\n                    ',
#  'Other Publications\n                    ',
#  'Our Rate Card\n                    ',
#  'Classifieds\n                    ',
#  'About Us\n                    ',
#  'Job Opportunities\n                    ',
#  'Investor Relations\n                    ',
#  'Contact Us\n                    ',
#  'FAQs\n                    ',
#  'Privacy Statement\n                    ',
#  'Terms & Conditions\n                    ',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n\n',
#  '\n',
#  '\n',
#  '\n\n',
#  '\n\n                        Home\n                    ',
#  '\n\n                        For You\n                    ',
#  '\n\n                        Bookmark\n                    ',
#  '\n',
#  '',
#  "\n{{item['V1 Header']}}\n  \xa0{{item['V1 Body']}}\n \n \xa0{{item['V2 Header']}}\n\n",
#  '',
#  'Download now!',
#  'Skip',
#  'Privacy Policy',
#  'Terms and Conditions',
#  'downloading']

# %% [markdown]
# ## Scraping for the information needed from the web page
#
# In Web scraping you will need to access the information to be scraped and **hunt** for the corresponding **HTML tags**
#
# For example the table shown on the left is the daily accumulated total cases, new cases, total death and total recovered. On the highlighted right side is the HTML.
#
# *(do this after intro to HTML class and id)*

# %% [markdown]
# <img src="./Images/Intro3.png">

# %%
# Scrape the table
import requests
from bs4 import BeautifulSoup

url='https://www.thestar.com.my/news/nation/2020/03/23/covid-19-current-situation-in-malaysia-updated-daily'

# get the webpage


# load webpage into bs4


# Find all div

# %%
print(len(soup_div)) # total items in the list
# Out:
# 343

# %%
print(soup_div[:10]) # print just only the first 10 items in the list
# Out:
# [<div class="stickyy">
# <div class="installApp" id="installContainer" style="display:none">
# <button id="btnClose" type="button"> × </button>
# <div id="imgBox">
# <img alt="The Star" onclick="false" src="/theme_metro/images/TSOL640x100.png"/>
# </div>
# <button id="btnAdd" type="button"> View </button>
# </div>
# </div>, <div class="installApp" id="installContainer" style="display:none">
# <button id="btnClose" type="button"> × </button>
# <div id="imgBox">
# <img alt="The Star" onclick="false" src="/theme_metro/images/TSOL640x100.png"/>
# </div>
# <button id="btnAdd" type="button"> View </button>
# </div>, <div id="imgBox">
# <img alt="The Star" onclick="false" src="/theme_metro/images/TSOL640x100.png"/>
# </div>, <div class="sassize"></div>, <div class="widgettop" id="widgettop" style="display:none;">
# <div class="flex-container">
# <div class="firinfo"></div>
# <div class="close">
# <img id="closeButton" src="https://cdn.thestar.com.my/Themes/img/close.png"/>
# </div>
# </div>
# </div>, <div class="flex-container">
# <div class="firinfo"></div>
# <div class="close">
# <img id="closeButton" src="https://cdn.thestar.com.my/Themes/img/close.png"/>
# </div>
# </div>, <div class="firinfo"></div>, <div class="close">
# <img id="closeButton" src="https://cdn.thestar.com.my/Themes/img/close.png"/>
# </div>, <div class="branding">
# <div class="container">
# <a class="navbar-brand brand-prime" data-content-id="https://www.thestar.com.my" data-content-title="The Star Online" data-content-type="Navigation" data-list-type="Header" href="/">
# <svg aria-label="the star online" class="icon" height="55" role="img" width="164">
# <image border="0" height="55" src="https://cdn.thestar.com.my/Themes/img/logo-tsol-logo.png" width="164" xlink:href="https://cdn.thestar.com.my/Themes/img/logo-tsol-full.svg"/>
# </svg>
# </a>
# <ul class="nav social-branding right">
# <!--                <li>
#                     <a href="https://newsstand.thestar.com.my/epaper/" target="_blank" class="epaper"
#                        data-list-type="Header"
#                        data-content-type="App Download"
#                        data-content-title="ePaper"
#                        data-content-id="https://newsstand.thestar.com.my/epaper/ ">
#                         <i class="icon sprite-icon"></i> The Star ePaper
#                     </a>
#                 </li>-->
# <li class="dropdown dropdown--subscribe top-bar">
# <a class="btn--subscribe" data-content-id="https://www.thestar.com.my/subscription" data-content-title="Subscription" data-content-type="Navigation" data-list-type="Header" href="/subscription">Subscriptions</a>
# </li>
# <li class="btn-login" id="btn_login">
# <a class="login" data-content-id="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=" data-content-title="Log In" data-content-type="Outbound Referral" data-list-type="Header" href="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=">
#                         Log In
#                      </a>
# </li>
# <li class="dropdown top-bar" id="login_menu" style="display:none;">
# <a class="log-in-light" id="hllogin"><i class="icon sprite-icon"></i></a>
# <ul class="dropdown-menu log-in 123">
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/profile.aspx" data-content-type="Manage Profile" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/profile.aspx" target="_blank">Manage Profile
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/changepassword.aspx" data-content-type="Change Password" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/changepassword.aspx" target="_blank">Change Password
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/sessions.aspx" data-content-type="Manage Logins" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/sessions.aspx" target="_blank">Manage Logins
#                                 </a>
# </li>
# <li style="border-top:1px solid #d6d6d6">
# <a data-content-title="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" data-content-type="Manage Subscription" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" target="_blank">Manage Subscription
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/transhistory.aspx" data-content-type="Transaction History" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/transhistory.aspx" target="_blank">Transaction History
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/billing.aspx" data-content-type="Manage Billing Info" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/billing.aspx" target="_blank">Manage Billing Info
#                                 </a>
# </li>
# <li style="border-top:1px solid #d6d6d6">
# <a data-content-title="https://www.thestar.com.my/foryou/edit" data-content-type="Manage For You" data-list-type="Profile Management" href="https://www.thestar.com.my/foryou/edit">Manage For You
#                                 </a>
# </li>
# <li style="border-bottom:1px solid #d6d6d6">
# <a data-content-title="https://www.thestar.com.my/saved-articles" data-content-type="Manage Bookmarks" data-list-type="Profile Management" href="https://www.thestar.com.my/saved-articles">Manage Bookmarks
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://www.thestar.com.my/subscribe" data-content-type="Package &amp; Pricing" data-list-type="Profile Management" href="https://www.thestar.com.my/subscribe">Package &amp; Pricing
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://www.thestar.com.my/faqs/" data-content-type="FAQs" data-list-type="Profile Management" href="https://www.thestar.com.my/faqs/">FAQs
#                                 </a>
# </li>
# <li class="log-out">
# <a data-content-title="https://www.thestar.com.my" data-content-type="Log Out" data-list-type="Profile Management" href="#" onclick="logout();">Log Out
#                                 </a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>, <div class="container">
# <a class="navbar-brand brand-prime" data-content-id="https://www.thestar.com.my" data-content-title="The Star Online" data-content-type="Navigation" data-list-type="Header" href="/">
# <svg aria-label="the star online" class="icon" height="55" role="img" width="164">
# <image border="0" height="55" src="https://cdn.thestar.com.my/Themes/img/logo-tsol-logo.png" width="164" xlink:href="https://cdn.thestar.com.my/Themes/img/logo-tsol-full.svg"/>
# </svg>
# </a>
# <ul class="nav social-branding right">
# <!--                <li>
#                     <a href="https://newsstand.thestar.com.my/epaper/" target="_blank" class="epaper"
#                        data-list-type="Header"
#                        data-content-type="App Download"
#                        data-content-title="ePaper"
#                        data-content-id="https://newsstand.thestar.com.my/epaper/ ">
#                         <i class="icon sprite-icon"></i> The Star ePaper
#                     </a>
#                 </li>-->
# <li class="dropdown dropdown--subscribe top-bar">
# <a class="btn--subscribe" data-content-id="https://www.thestar.com.my/subscription" data-content-title="Subscription" data-content-type="Navigation" data-list-type="Header" href="/subscription">Subscriptions</a>
# </li>
# <li class="btn-login" id="btn_login">
# <a class="login" data-content-id="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=" data-content-title="Log In" data-content-type="Outbound Referral" data-list-type="Header" href="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=">
#                         Log In
#                      </a>
# </li>
# <li class="dropdown top-bar" id="login_menu" style="display:none;">
# <a class="log-in-light" id="hllogin"><i class="icon sprite-icon"></i></a>
# <ul class="dropdown-menu log-in 123">
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/profile.aspx" data-content-type="Manage Profile" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/profile.aspx" target="_blank">Manage Profile
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/changepassword.aspx" data-content-type="Change Password" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/changepassword.aspx" target="_blank">Change Password
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/sessions.aspx" data-content-type="Manage Logins" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/sessions.aspx" target="_blank">Manage Logins
#                                 </a>
# </li>
# <li style="border-top:1px solid #d6d6d6">
# <a data-content-title="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" data-content-type="Manage Subscription" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" target="_blank">Manage Subscription
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/transhistory.aspx" data-content-type="Transaction History" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/transhistory.aspx" target="_blank">Transaction History
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/billing.aspx" data-content-type="Manage Billing Info" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/billing.aspx" target="_blank">Manage Billing Info
#                                 </a>
# </li>
# <li style="border-top:1px solid #d6d6d6">
# <a data-content-title="https://www.thestar.com.my/foryou/edit" data-content-type="Manage For You" data-list-type="Profile Management" href="https://www.thestar.com.my/foryou/edit">Manage For You
#                                 </a>
# </li>
# <li style="border-bottom:1px solid #d6d6d6">
# <a data-content-title="https://www.thestar.com.my/saved-articles" data-content-type="Manage Bookmarks" data-list-type="Profile Management" href="https://www.thestar.com.my/saved-articles">Manage Bookmarks
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://www.thestar.com.my/subscribe" data-content-type="Package &amp; Pricing" data-list-type="Profile Management" href="https://www.thestar.com.my/subscribe">Package &amp; Pricing
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://www.thestar.com.my/faqs/" data-content-type="FAQs" data-list-type="Profile Management" href="https://www.thestar.com.my/faqs/">FAQs
#                                 </a>
# </li>
# <li class="log-out">
# <a data-content-title="https://www.thestar.com.my" data-content-type="Log Out" data-list-type="Profile Management" href="#" onclick="logout();">Log Out
#                                 </a>
# </li>
# </ul>
# </li>
# </ul>
# </div>]

# %%
print(soup_div[-10:]) # print just only the last 10 items in the list
# Out:
# [<div class="validate"></div>, <div class="skip"><a id="widget-skip">Skip</a></div>, <div class="term"><div>Disclaimer: by clicking the Submit button, it is deemed that you consent to the rules and terms set forth in the <a href="https://www.thestar.com.my/privacy/" target="_blank">Privacy Policy</a> as well as <a href="https://www.thestar.com.my/terms/" target="_blank">Terms and Conditions</a> set forth by this site.</div></div>, <div>Disclaimer: by clicking the Submit button, it is deemed that you consent to the rules and terms set forth in the <a href="https://www.thestar.com.my/privacy/" target="_blank">Privacy Policy</a> as well as <a href="https://www.thestar.com.my/terms/" target="_blank">Terms and Conditions</a> set forth by this site.</div>, <div class="thankYouBox thanks" style="display: none;margin-left: 40px;"><div class="flex-container thanksbox"><div class="svg-down"></div><div><h3 style="display: block; font-size: 1.17em; margin-block-end: 1em; margin-inline-start: 0px;margin-inline-end: 0px; fontweight: bold;">Thank you for downloading.</h3></div></div><div class="flex-container"><div><p>We hope you enjoy this feature!</p><span>Didn't work? Try <a class="widget-link2" id="widget-link2">downloading</a> again.</span></div></div></div>, <div class="flex-container thanksbox"><div class="svg-down"></div><div><h3 style="display: block; font-size: 1.17em; margin-block-end: 1em; margin-inline-start: 0px;margin-inline-end: 0px; fontweight: bold;">Thank you for downloading.</h3></div></div>, <div class="svg-down"></div>, <div><h3 style="display: block; font-size: 1.17em; margin-block-end: 1em; margin-inline-start: 0px;margin-inline-end: 0px; fontweight: bold;">Thank you for downloading.</h3></div>, <div class="flex-container"><div><p>We hope you enjoy this feature!</p><span>Didn't work? Try <a class="widget-link2" id="widget-link2">downloading</a> again.</span></div></div>, <div><p>We hope you enjoy this feature!</p><span>Didn't work? Try <a class="widget-link2" id="widget-link2">downloading</a> again.</span></div>]

# %%
# Find ALl Containers
# Out:
# [<div class="container">
#  <a class="navbar-brand brand-prime" data-content-id="https://www.thestar.com.my" data-content-title="The Star Online" data-content-type="Navigation" data-list-type="Header" href="/">
#  <svg aria-label="the star online" class="icon" height="55" role="img" width="164">
#  <image border="0" height="55" src="https://cdn.thestar.com.my/Themes/img/logo-tsol-logo.png" width="164" xlink:href="https://cdn.thestar.com.my/Themes/img/logo-tsol-full.svg"/>
#  </svg>
#  </a>
#  <ul class="nav social-branding right">
#  <!--                <li>
#                      <a href="https://newsstand.thestar.com.my/epaper/" target="_blank" class="epaper"
#                         data-list-type="Header"
#                         data-content-type="App Download"
#                         data-content-title="ePaper"
#                         data-content-id="https://newsstand.thestar.com.my/epaper/ ">
#                          <i class="icon sprite-icon"></i> The Star ePaper
#                      </a>
#                  </li>-->
#  <li class="dropdown dropdown--subscribe top-bar">
#  <a class="btn--subscribe" data-content-id="https://www.thestar.com.my/subscription" data-content-title="Subscription" data-content-type="Navigation" data-list-type="Header" href="/subscription">Subscriptions</a>
#  </li>
#  <li class="btn-login" id="btn_login">
#  <a class="login" data-content-id="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=" data-content-title="Log In" data-content-type="Outbound Referral" data-list-type="Header" href="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=">
#                          Log In
#                       </a>
#  </li>
#  <li class="dropdown top-bar" id="login_menu" style="display:none;">
#  <a class="log-in-light" id="hllogin"><i class="icon sprite-icon"></i></a>
#  <ul class="dropdown-menu log-in 123">
#  <li>
#  <a data-content-title="https://login.thestar.com.my/accountinfo/profile.aspx" data-content-type="Manage Profile" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/profile.aspx" target="_blank">Manage Profile
#                                  </a>
#  </li>
#  <li>
#  <a data-content-title="https://login.thestar.com.my/accountinfo/changepassword.aspx" data-content-type="Change Password" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/changepassword.aspx" target="_blank">Change Password
#                                  </a>
#  </li>
#  <li>
#  <a data-content-title="https://login.thestar.com.my/accountinfo/sessions.aspx" data-content-type="Manage Logins" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/sessions.aspx" target="_blank">Manage Logins
#                                  </a>
#  </li>
#  <li style="border-top:1px solid #d6d6d6">
#  <a data-content-title="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" data-content-type="Manage Subscription" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" target="_blank">Manage Subscription
#                                  </a>
#  </li>
#  <li>
#  <a data-content-title="https://login.thestar.com.my/accountinfo/transhistory.aspx" data-content-type="Transaction History" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/transhistory.aspx" target="_blank">Transaction History
#                                  </a>
#  </li>
#  <li>
#  <a data-content-title="https://login.thestar.com.my/accountinfo/billing.aspx" data-content-type="Manage Billing Info" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/billing.aspx" target="_blank">Manage Billing Info
#                                  </a>
#  </li>
#  <li style="border-top:1px solid #d6d6d6">
#  <a data-content-title="https://www.thestar.com.my/foryou/edit" data-content-type="Manage For You" data-list-type="Profile Management" href="https://www.thestar.com.my/foryou/edit">Manage For You
#                                  </a>
#  </li>
#  <li style="border-bottom:1px solid #d6d6d6">
#  <a data-content-title="https://www.thestar.com.my/saved-articles" data-content-type="Manage Bookmarks" data-list-type="Profile Management" href="https://www.thestar.com.my/saved-articles">Manage Bookmarks
#                                  </a>
#  </li>
#  <li>
#  <a data-content-title="https://www.thestar.com.my/subscribe" data-content-type="Package &amp; Pricing" data-list-type="Profile Management" href="https://www.thestar.com.my/subscribe">Package &amp; Pricing
#                                  </a>
#  </li>
#  <li>
#  <a data-content-title="https://www.thestar.com.my/faqs/" data-content-type="FAQs" data-list-type="Profile Management" href="https://www.thestar.com.my/faqs/">FAQs
#                                  </a>
#  </li>
#  <li class="log-out">
#  <a data-content-title="https://www.thestar.com.my" data-content-type="Log Out" data-list-type="Profile Management" href="#" onclick="logout();">Log Out
#                                  </a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  </div>,
#  <div class="container">
#  <div class="navbar-header">
#  <button class="navbar-toggle left" data-target="#tsolmobar" data-toggle="collapse" type="button">
#  <span class="sr-only">Toggle navigation</span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  <i class="icon-x fa fa-times"></i>
#  </button>
#  <a class="navbar-brand brand-mobile left" data-content-id="https://www.thestar.com.my" data-content-title="The Star Online" data-content-type="Navigation" data-list-type="Header" href="/">
#  <svg aria-label="the star online" class="icon" height="26" role="img" width="70">
#  <image border="0" height="26" src="https://cdn.thestar.com.my/Themes/img/logo-tsol-mobile.png" width="70" xlink:href="https://cdn.thestar.com.my/Themes/img/logo-tsol-full.svg" xmlns:xlink="http://www.w3.org/1999/xlink"/>
#  </svg>
#  </a>
#  </div>
#  <div id="tsolnavbar">
#  <ul class="nav navbar-nav navbar-left">
#  <li class="show-sd">
#  <button aria-expanded="false" class="mega-nav-toggle navbar-toggle collapsed hidden-xs" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
#  <span class="sr-only">Toggle navigation</span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  <i class="icon-x fa fa-times"></i>
#  </button>
#  </li>
#  <li>
#  <a class="home-light" data-content-id="https://www.thestar.com.my" data-content-title="Home" data-content-type="Navigation" data-list-type="Header" href="/" id="navi-home" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Home/' ); " target="">
#  <i class="icon sprite-icon"></i>
#  </a>
#  </li>
#  <li class="dropdown">
#  <a class="starplus" data-content-id="https://www.thestar.com.my/starplus" data-content-title="StarPlus" data-content-type="Navigation" data-list-type="Header" href="/starplus" id="navi-starplus" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/StarPlus/' ); " target="">
#                      StarPlus
#                      </a>
#  </li>
#  <li class="dropdown">
#  <a class="news" data-content-id="https://www.thestar.com.my/news" data-content-title="News" data-content-type="Navigation" data-list-type="Header" href="/news" id="navi-news" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/News/' ); " target="">
#                      News
#                      </a>
#  </li>
#  <li class="dropdown">
#  <a class="asean+" data-content-id="https://www.thestar.com.my/aseanplus" data-content-title="Asean+" data-content-type="Navigation" data-list-type="Header" href="/aseanplus" id="navi-asean+" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/AseanPlus/' ); " target="">
#                      Asean+
#                      </a>
#  </li>
#  <li class="dropdown">
#  <a class="business" data-content-id="https://www.thestar.com.my/business" data-content-title="Business" data-content-type="Navigation" data-list-type="Header" href="/business" id="navi-business" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Business/' ); " target="">
#                      Business
#                      </a>
#  </li>
#  <li class="dropdown">
#  <a class="sport" data-content-id="https://www.thestar.com.my/sport" data-content-title="Sport" data-content-type="Navigation" data-list-type="Header" href="/sport" id="navi-sport" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Sport/' ); " target="">
#                      Sport
#                      </a>
#  </li>
#  <li class="dropdown">
#  <a class="metro" data-content-id="https://www.thestar.com.my/metro" data-content-title="Metro" data-content-type="Navigation" data-list-type="Header" href="/metro" id="navi-metro" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Metro/' ); " target="">
#                      Metro
#                      </a>
#  </li>
#  <li class="dropdown">
#  <a class="lifestyle" data-content-id="https://www.thestar.com.my/lifestyle" data-content-title="Lifestyle" data-content-type="Navigation" data-list-type="Header" href="/lifestyle" id="navi-lifestyle" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Lifestyle/' ); " target="">
#                      Lifestyle
#                      </a>
#  </li>
#  <li class="dropdown">
#  <a class="food" data-content-id="https://www.thestar.com.my/food" data-content-title="Food" data-content-type="Navigation" data-list-type="Header" href="/food" id="navi-food" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Food/' ); " target="">
#                      Food
#                      </a>
#  </li>
#  <li class="dropdown">
#  <a class="tech" data-content-id="https://www.thestar.com.my/tech" data-content-title="Tech" data-content-type="Navigation" data-list-type="Header" href="/tech" id="navi-tech" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Tech/' ); " target="">
#                      Tech
#                      </a>
#  </li>
#  <li class="dropdown">
#  <a class="education" data-content-id="https://www.thestar.com.my/education" data-content-title="Education" data-content-type="Navigation" data-list-type="Header" href="/education" id="navi-education" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Education/' ); " target="">
#                      Education
#                      </a>
#  </li>
#  <li class="dropdown">
#  <a class="opinion" data-content-id="https://www.thestar.com.my/opinion" data-content-title="Opinion" data-content-type="Navigation" data-list-type="Header" href="/opinion" id="navi-opinion" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Opinion/' ); " target="">
#                      Opinion
#                      </a>
#  </li>
#  <li class="dropdown">
#  <a class="videos" data-content-id="https://www.thestartv.com/c/news" data-content-title="Videos" data-content-type="Outbound Referral" data-list-type="Header" href="https://www.thestartv.com/c/news" id="navi-videos" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , 'https://www.thestartv.com/c/news' ); " style="" target="_blank">
#                      Videos
#                      </a>
#  </li>
#  <li class="dropdown">
#  <a class="photos" data-content-id="https://www.thestar.com.my/photos" data-content-title="Photos" data-content-type="Navigation" data-list-type="Header" href="/photos" id="navi-photos" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Photos/' ); " target="">
#                      Photos
#                      </a>
#  </li>
#  <li class="dropdown">
#  <a class="starpicks" data-content-id="https://www.thestar.com.my/starpicks" data-content-title="StarPicks" data-content-type="Navigation" data-list-type="Header" href="/starpicks" id="navi-starpicks" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Starpicks/' ); " target="">
#                      StarPicks
#                      </a>
#  </li>
#  </ul>
#  </div>
#  <ul class="nav navbar-nav navbar-right">
#  <li class="hidden-lg dropdown dropdown--subscribe">
#  <a aria-expanded="false" class="btn--subscribe dropdown-toggle" data-prokeyscachednode="false" onclick="toggleSubDrop()" role="button">Subscriptions</a>
#  <ul class="dropdown-menu" id="subDrop" style="display: none;">
#  <li>
#  <a data-content-id="https://www.thestar.com.my/subscribe" data-content-title="The Star Digital Access" data-content-type="Navigation" data-list-type="Header" href="/subscribe">The Star Digital Access</a>
#  </li>
#  <li>
#  <a data-content-id="https://newsstand.thestar.com.my/" data-content-title="Newsstand" data-content-type="Outbound Referral" data-list-type="Header" href="https://newsstand.thestar.com.my/">Newsstand</a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/sms-services" data-content-title="SMS Services" data-content-type="Navigation" data-list-type="Header" href="/sms-services">SMS Services</a>
#  </li>
#  </ul>
#  </li>
#  <li class="m-login-button hidden-md hidden-lg" id="btn_login" style="display: none;">
#  <a class="login bttn bttn--log" data-content-id="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=" data-content-title="Log In" data-content-type="Outbound Referral" data-list-type="Header" href="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=">Log In
#                      </a>
#  </li>
#  <li class="m-login-menu hidden-md hidden-lg" id="login_menu" style="display:none;">
#  <a class="log-in" id="hllogin" onclick="toggleDrop()"><i class="icon sprite-icon"></i></a>
#  <ul class="dropdown-menu log-in" id="loginDrop" style="display: none;">
#  <li>
#  <a data-content-title="https://login.thestar.com.my/accountinfo/profile.aspx" data-content-type="Manage Profile" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/profile.aspx" target="_blank">Manage Profile
#                              </a>
#  </li>
#  <li>
#  <a data-content-title="https://login.thestar.com.my/accountinfo/changepassword.aspx" data-content-type="Change Password" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/changepassword.aspx" target="_blank">Change Password
#                              </a>
#  </li>
#  <li>
#  <a data-content-title="https://login.thestar.com.my/accountinfo/sessions.aspx" data-content-type="Manage Logins" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/sessions.aspx" target="_blank">Manage Logins
#                              </a>
#  </li>
#  <li style="border-top:1px solid #d6d6d6">
#  <a data-content-title="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" data-content-type="Manage Subscription" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" target="_blank">Manage Subscription
#                              </a>
#  </li>
#  <li>
#  <a data-content-title="https://login.thestar.com.my/accountinfo/transhistory.aspx" data-content-type="Transaction History" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/transhistory.aspx" target="_blank">Transaction History
#                              </a>
#  </li>
#  <li>
#  <a data-content-title="https://login.thestar.com.my/accountinfo/billing.aspx" data-content-type="Manage Billing Info" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/billing.aspx" target="_blank">Manage Billing Info
#                              </a>
#  </li>
#  <li style="border-top:1px solid #d6d6d6">
#  <a data-content-title="https://www.thestar.com.my/foryou/edit" data-content-type="Manage For You" data-list-type="Profile Management" href="https://www.thestar.com.my/foryou/edit">Manage For You
#                              </a>
#  </li>
#  <li style="border-bottom:1px solid #d6d6d6">
#  <a data-content-title="https://www.thestar.com.my/saved-articles" data-content-type="Manage Bookmarks" data-list-type="Profile Management" href="https://www.thestar.com.my/saved-articles">Manage Bookmarks
#                              </a>
#  </li>
#  <li>
#  <a data-content-title="https://www.thestar.com.my/subscribe" data-content-type="Package &amp; Pricing" data-list-type="Profile Management" href="https://www.thestar.com.my/subscribe">Package &amp; Pricing
#                              </a>
#  </li>
#  <li>
#  <a data-content-title="https://www.thestar.com.my/faqs/" data-content-type="FAQs" data-list-type="Profile Management" href="https://www.thestar.com.my/faqs/">FAQs
#                              </a>
#  </li>
#  <li class="log-out">
#  <a data-content-title="https://www.thestar.com.my" data-content-type="Log Out" data-list-type="Profile Management" href="#" onclick="logout();">Log Out
#                              </a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  </div>,
#  <div class="container searchbardiv">
#  <form id="searchform2" method="post" role="search">
#  <div class="input-group">
#  <input class="form-control" id="qTextBox2" onkeypress="searchKeyPress(event, 'btnSearch2' ); " placeholder="What are you looking for?" type="text"/>
#  <div id="qStockCodeHolder">
#  <input id="qStockCodeVal2" type="hidden" value="">
#  </input></div>
#  <div class="input-group-btn">
#  <input class="btn btn-default" id="btnSearch2" onclick="jQuery('#qTextBox2').addClass('loadinggif'); post('/search/', { q: document.getElementById('qTextBox2').value, qsort: 'newest', qrec: '10', qstockcode: document.getElementById('qStockCodeVal2').value }, 'get');ga('send', 'event', 'TSOL NAVI', 'Extra-Panel', 'Search Button'); " style="font-weight: bold" type="button" value="Search"/>
#  <a class="btn btn-default adv-search-link" data-content-id="https://www.thestar.com.my/search/?adv=1" data-content-title="Advance Search" data-content-type="Navigation" data-list-type="Header" href="/search?adv=1" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Extra-Panel' , 'Advance Search' ); " onmousedown="searchAdvanceClick(this,'qTextBox2')" style="font-weight: 900"><i class="icon sprite-icon plus"></i>
#  </a>
#  </div>
#  </div>
#  </form>
#  </div>,
#  <div class="container">
#  <div class="row">
#  <div class="mega-nav__col">
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my" data-content-title="Home" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/" onclick="ga('send', 'event', 'TSOL MEGA NAVI', 'Standard', '/Home/');" target="_self">Home
#                                  </a>
#  </div>
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/starplus" data-content-title="StarPlus" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/starplus" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/StarPlus/' ); " target="">
#                                  StarPlus
#                              </a>
#  </div>
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/news" data-content-title="News" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/' ); " target="">
#                                  News
#                              </a>
#  <ul class="mega-nav__list">
#  <li>
#  <a data-content-id="https://www.thestar.com.my/news/latest" data-content-title="Latest" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news/latest" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/Latest/' ); " target="">Latest
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/news/nation" data-content-title="Nation" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news/nation" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/Nation/' ); " target="">Nation
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/news/world" data-content-title="World" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news/world" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/World/' ); " target="">World
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/news/environment" data-content-title="Environment" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news/environment" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/Environment/' ); " target="">Environment
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/news/in-other-media" data-content-title="In Other Media" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news/in-other-media" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/In-Other-Media/' ); " target="">In Other Media
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/news/true-or-not" data-content-title="True or Not" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news/true-or-not" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/True-Or-Not/' ); " target="">True or Not
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/news/focus" data-content-title="Focus" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/news/focus" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/News/Focus/' ); " target="">Focus
#                                      </a>
#  </li>
#  </ul>
#  </div>
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/aseanplus" data-content-title="Asean+" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/aseanplus" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/AseanPlus/' ); " target="">
#                                  Asean+
#                              </a>
#  </div>
#  </div>
#  <div class="mega-nav__col">
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/business" data-content-title="Business" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/' ); " target="">
#                                  Business
#                              </a>
#  <ul class="mega-nav__list">
#  <li>
#  <a data-content-id="https://www.thestar.com.my/business" data-content-title="News" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/' ); " target="">News
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/business/smebiz" data-content-title="SMEBiz" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/smebiz" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Smebiz/' ); " target="">SMEBiz
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/business/insight" data-content-title="Insight" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/insight" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Insight/' ); " target="">Insight
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/business/unit-trust" data-content-title="Unit Trust" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/unit-trust" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Unit-Trust/' ); " target="">Unit Trust
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/business/exchange-rates" data-content-title="Exchange Rates" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/exchange-rates" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Exchange-Rates/' ); " target="">Exchange Rates
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="http://biz.thestar.com.my/portfolio/" data-content-title="My Portfolio" data-content-type="Outbound Referral" data-list-type="Header Mega Menu" href="http://biz.thestar.com.my/portfolio/" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , 'http://biz.thestar.com.my/portfolio/' ); " target="_blank">My Portfolio
#                                      </a>
#  </li>
#  </ul>
#  </div>
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/business/marketwatch" data-content-title="Market Watch" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/marketwatch" onclick="ga('send', 'event', 'TSOL MEGA NAVI', 'Standard', '/Business/MarketWatch/');" target="">
#                                  Market Watch
#                              </a>
#  <ul class="mega-nav__list">
#  <li>
#  <a data-content-id="https://www.thestar.com.my/business/marketwatch" data-content-title="Bursa Overview" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/marketwatch" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Marketwatch/' ); " target="">Bursa Overview
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/business/martketwatch/stock-list" data-content-title="Market Movers" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/martketwatch/Stock-List" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Martketwatch/Stock-List/' ); " target="">Market Movers
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/business/martketwatch/financial-results" data-content-title="Financial Results" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/martketwatch/Financial-Results" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Martketwatch/Financial-Results/' ); " target="">Financial Results
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/business/martketwatch/dividends" data-content-title="Dividends" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/martketwatch/Dividends" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Martketwatch/Dividends/' ); " target="">Dividends
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/business/martketwatch/bonus" data-content-title="Bonus" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/martketwatch/Bonus" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Martketwatch/Bonus/' ); " target="">Bonus
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/business/martketwatch/ipo" data-content-title="IPO" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/business/martketwatch/IPO" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Business/Martketwatch/IPO/' ); " target="">IPO
#                                      </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="mega-nav__col">
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/sport" data-content-title="Sport" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/' ); " target="">
#                                  Sport
#                              </a>
#  <ul class="mega-nav__list">
#  <li>
#  <a data-content-id="https://www.thestar.com.my/sport/football" data-content-title="Football" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/football" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Football/' ); " target="">Football
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/sport/golf" data-content-title="Golf" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/golf" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Golf/' ); " target="">Golf
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/sport/badminton" data-content-title="Badminton" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/badminton" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Badminton/' ); " target="">Badminton
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/sport/tennis" data-content-title="Tennis" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/tennis" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Tennis/' ); " target="">Tennis
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/sport/motorsport" data-content-title="Motorsport" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/motorsport" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Motorsport/' ); " target="">Motorsport
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/sport/athletics" data-content-title="Athletics" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/athletics" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Athletics/' ); " target="">Athletics
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/sport/hockey" data-content-title="Hockey" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/hockey" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Hockey/' ); " target="">Hockey
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/sport/other-sport" data-content-title="Other Sports" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/other-sport" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Other-Sport/' ); " target="">Other Sports
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/sport/say-what" data-content-title="Say What" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/sport/say-what" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Sport/Say-What/' ); " target="">Say What
#                                      </a>
#  </li>
#  </ul>
#  </div>
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/metro" data-content-title="Metro" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/metro" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Metro/' ); " target="">
#                                  Metro
#                              </a>
#  <ul class="mega-nav__list">
#  <li>
#  <a data-content-id="https://www.thestar.com.my/metro/metro-news" data-content-title="Metro News" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/metro/metro-news" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Metro/Metro-News/' ); " target="">Metro News
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/metro/community-sports" data-content-title="Community Sports" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/metro/community-sports" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Metro/Community-Sports/' ); " target="">Community Sports
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/metro/views" data-content-title="Views" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/metro/views" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Metro/Views/' ); " target="">Views
#                                      </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="mega-nav__col">
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/lifestyle" data-content-title="Lifestyle" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/lifestyle" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Lifestyle/' ); " target="">
#                                  Lifestyle
#                              </a>
#  <ul class="mega-nav__list">
#  <li>
#  <a data-content-id="https://www.thestar.com.my/lifestyle/entertainment-and-style" data-content-title="Entertainment &amp;amp; Style" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/lifestyle/entertainment-and-style" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Lifestyle/Entertainment-And-Style/' ); " target="">Entertainment &amp; Style
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/lifestyle/people-and-living" data-content-title="People &amp;amp; Living" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/lifestyle/people-and-living" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Lifestyle/People-And-Living/' ); " target="">People &amp; Living
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/lifestyle/health-and-family" data-content-title="Health &amp;amp; Family" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/lifestyle/health-and-family" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Lifestyle/Health-And-Family/' ); " target="">Health &amp; Family
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/lifestyle/travel-and-culture" data-content-title="Travel &amp;amp; Culture" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/lifestyle/travel-and-culture" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Lifestyle/Travel-And-Culture/' ); " target="">Travel &amp; Culture
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/lifestyle/viewpoints" data-content-title="Viewpoints" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/lifestyle/viewpoints" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Lifestyle/Viewpoints/' ); " target="">Viewpoints
#                                      </a>
#  </li>
#  </ul>
#  </div>
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/food" data-content-title="Food" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/food" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Food/' ); " target="">
#                                  Food
#                              </a>
#  <ul class="mega-nav__list">
#  <li>
#  <a data-content-id="https://www.thestar.com.my/food/food-news" data-content-title="Food News" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/food/food-news" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Food/Food-News/' ); " target="">Food News
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/food/eating-out" data-content-title="Eating Out" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/food/eating-out" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Food/Eating-Out/' ); " target="">Eating Out
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/food/food-for-thought" data-content-title="Food for Thought" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/food/food-for-thought" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Food/Food-for-Thought/' ); " target="">Food for Thought
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.kuali.com/" data-content-title="Kuali" data-content-type="Outbound Referral" data-list-type="Header Mega Menu" href="https://www.kuali.com/" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , 'https://www.kuali.com/' ); " target="_blank">Kuali
#                                      </a>
#  </li>
#  </ul>
#  </div>
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/tech" data-content-title="Tech" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/tech" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Tech/' ); " target="">
#                                  Tech
#                              </a>
#  <ul class="mega-nav__list">
#  <li>
#  <a data-content-id="https://www.thestar.com.my/tech/tech-thoughts" data-content-title="Tech Thoughts" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/tech/tech-thoughts" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Tech/Tech-Thoughts/' ); " target="">Tech Thoughts
#                                      </a>
#  </li>
#  </ul>
#  </div>
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/education" data-content-title="Education" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/education" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Education/' ); " target="">
#                                  Education
#                              </a>
#  <ul class="mega-nav__list">
#  <li>
#  <a data-content-id="https://www.thestar.com.my/education/news" data-content-title="News" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/education/news" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Mobile' , '/Education/News/' ); " target="">News
#                                      </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="mega-nav__col">
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/opinion" data-content-title="Opinion" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/opinion" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Opinion/' ); " target="">
#                                  Opinion
#                              </a>
#  <ul class="mega-nav__list">
#  <li>
#  <a data-content-id="https://www.thestar.com.my/opinion/columnists" data-content-title="Columnists" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/opinion/columnists" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Opinion/Columnists/' ); " target="">Columnists
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.thestar.com.my/opinion/letters" data-content-title="Letters" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/opinion/letters" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Opinion/Letters/' ); " target="">Letters
#                                      </a>
#  </li>
#  </ul>
#  </div>
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestartv.com/c/news" data-content-title="Videos" data-content-type="Outbound Referral" data-list-type="Header Mega Menu" href="https://www.thestartv.com/c/news" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , 'https://www.thestartv.com/c/news' ); " target="_blank">
#                                  Videos
#                              </a>
#  </div>
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/photos" data-content-title="Photos" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/photos" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/Photos/' ); " target="">
#                                  Photos
#                              </a>
#  </div>
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my/starpicks" data-content-title="StarPicks" data-content-type="Navigation" data-list-type="Header Mega Menu" href="/starpicks" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/StarPicks/' ); " target="">
#                                  StarPicks
#                              </a>
#  </div>
#  <div class="mega-nav__inner">
#  <a class="mega-nav__title" data-content-id="https://www.thestar.com.my" data-content-title="More" data-content-type="Navigation" data-list-type="Header Mega Menu" href="#" id="mega_more" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , '/More/' ); " target="">
#                                  More
#                              </a>
#  <ul class="mega-nav__list">
#  <li>
#  <a data-content-id="https://thestarmall.com.my/collections/the-star?utm_source=tsol&amp;utm_medium=meganavi&amp;utm_campaign=general" data-content-title="The Star Mall" data-content-type="Outbound Referral" data-list-type="Header Mega Menu" href="https://thestarmall.com.my/collections/the-star?utm_source=tsol&amp;utm_medium=meganavi&amp;utm_campaign=general" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , 'https://thestarmall.com.my/collections/the-star?utm_source=TSOL&amp;utm_medium=MegaNavi&amp;utm_campaign=General' ); " target="_blank">The Star Mall
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://promocodes.thestar.com.my/" data-content-title="Vouchers" data-content-type="Outbound Referral" data-list-type="Header Mega Menu" href="https://promocodes.thestar.com.my/" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , 'https://promocodes.thestar.com.my/' ); " target="_blank">Vouchers
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://starsearch.thestar.com.my/" data-content-title="Classifieds" data-content-type="Outbound Referral" data-list-type="Header Mega Menu" href="https://starsearch.thestar.com.my/" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , 'https://starsearch.thestar.com.my/' ); " target="_blank">Classifieds
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://events.thestar.com.my/" data-content-title="Events" data-content-type="Outbound Referral" data-list-type="Header Mega Menu" href="https://events.thestar.com.my/" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , 'https://events.thestar.com.my/' ); " target="_blank">Events
#                                      </a>
#  </li>
#  <li>
#  <a data-content-id="https://www.starcherish.com/" data-content-title="StarCherish.com" data-content-type="Outbound Referral" data-list-type="Header Mega Menu" href="https://www.starcherish.com/" onclick="ga('send', 'event' , 'TSOL MEGA NAVI' , 'Standard' , 'https://www.starcherish.com/' ); " target="_blank">StarCherish.com
#                                      </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="container">
#  <div class="row">
#  <div class="col-md-12 noPadding col-xs-12">
#  <!--wide-headline-image-widget.blade.php-->
#  <style type="text/css">
#  	.story-wide .headline {
#  	    border-bottom: none;
#  	    text-align: center;
#  	    padding: 0 30px;
#  	}
#
#  	.story-wide .headline hr {
#  	    left: 0;
#  	    right: 0;
#  	    margin: 0 auto;
#  	}
#  	.padding-top {
#  		padding-top: 25px!important;
#  	}
#  	.thumb__head {
#  		background-color: #eeeeee;
#  		width: 100%;
#  		overflow: hidden;
#  		position: relative;
#  		padding-bottom: 41.7%;
#  	}
#  	.story-set-group img {
#  		position: absolute;
#  		height: 100%;
#  		width: 100%;
#  		-o-object-fit: cover;
#  		object-fit: cover;
#  		-o-object-position: center center;
#  		object-position: center 10%;
#  	}
#  </style>
#  </div>
#  </div>
#  </div>,
#  <div class="container">
#  <div class="row">
#  <div class="col-md-8 col-xs-12">
# ...
#  </script>
#  <script src="https://cdn.thestar.com.my/Themes/js/recommendedreadingarticle.min.js?v=20201130" type="text/javascript"></script>
#  <!-- widget-2164 -->
#  <div id="widget-2164">
#  <script>
#    var widgetId = '2164';
#    if (rmad) {
#       $("#widget-" + widgetId).remove();
#    }
#  </script>
#  <div class="inlineAd" style="display:none">
#  <style>
#  #div-gpt-ad-Desktop_TSOL_News_SP_Mid_OSV div div {z-index:0;}
#  #div-gpt-ad-Mobile_TSOL_News_SP_Mid_OSV div div {z-index:0;}
#  </style>
#  <script>
#  if(!jQuery('#LB24').length && !jQuery('#LB24_LIVE_CONTENT').length){
#  if (sascalcsize() != "mobile") {
#  document.write("<div id='div-gpt-ad-Desktop_TSOL_News_SP_Mid_OSV'>");
#  document.write("<scr");
#  document.write("ipt>");
#  document.write("cX.callQueue.push(['invoke', function() { ");
#  document.write("googletag.cmd.push(function() { googletag.display('div-gpt-ad-Desktop_TSOL_News_SP_Mid_OSV'); });");
#  document.write("refreshBid('div-gpt-ad-Desktop_TSOL_News_SP_Mid_OSV', 10);");
#  document.write("}]);");
#  document.write("</scr");
#  document.write("ipt>");
#  document.write("</div>");
#  } else {
#  document.write("<div id='div-gpt-ad-Mobile_TSOL_News_SP_Mid_OSV'>");
#  document.write("<scr");
#  document.write("ipt>");
#  document.write("cX.callQueue.push(['invoke', function() { ");
#  document.write("googletag.cmd.push(function() { googletag.display('div-gpt-ad-Mobile_TSOL_News_SP_Mid_OSV'); });");
#  document.write("refreshBid('div-gpt-ad-Mobile_TSOL_News_SP_Mid_OSV', 9);");
#  document.write("}]);");
#  document.write("</scr");
#  document.write("ipt>");
#  document.write("</div>");
#  }
#  }
#  </script>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4 col-xs-12">
#  <!--dynamic-html.blade.php-->
#  <div id="widget-2123">
#  <script src="https://s3-ap-southeast-1.amazonaws.com/biz.thestar.com.my/json/chartdatetime.js"></script><script src="https://s3-ap-southeast-1.amazonaws.com/biz.thestar.com.my/js/plugins/jquery.jqplot.min.js" type="text/javascript"></script><script src="https://s3-ap-southeast-1.amazonaws.com/biz.thestar.com.my/js/plugins/jqplot.canvasTextRenderer.min.js" type="text/javascript"></script><script src="https://s3-ap-southeast-1.amazonaws.com/biz.thestar.com.my/js/plugins/jqplot.canvasAxisTickRenderer.min.js" type="text/javascript"></script><script src="https://s3-ap-southeast-1.amazonaws.com/biz.thestar.com.my/js/plugins/jqplot.dateAxisRenderer.min.js" type="text/javascript"></script><script src="https://s3-ap-southeast-1.amazonaws.com/biz.thestar.com.my/js/plugins/jqplot.canvasOverlay.min.js" type="text/javascript"></script><script src="https://s3-ap-southeast-1.amazonaws.com/biz.thestar.com.my/layout_v2/marketsummary/klciside.js"></script><script src="https://s3-ap-southeast-1.amazonaws.com/biz.thestar.com.my/layout/marketsummary/plotchart.js"></script><div id="div_chart"></div><script src="https://s3-ap-southeast-1.amazonaws.com/biz.thestar.com.my/json/top15active.js"></script><script src="https://s3-ap-southeast-1.amazonaws.com/biz.thestar.com.my/layout_v2/sidemarketmovers_v2.js"></script><div id="div_sidemarket_v2"></div><script>if (location.pathname.indexOf('/business/') === -1) { jQuery('#div_chart').hide(); jQuery('#div_sidemarket_v2').hide(); }</script>
#  </div>
#  <!-- widget-3846 -->
#  <div id="widget-3846">
#  <script>
#    var widgetId = '3846';
#    if (rmad) {
#       $("#widget-" + widgetId).remove();
#    }
#  </script>
#  <div class="Ads-slot"><div class="ads"><div class="med-rec"><script language="JavaScript" type="text/javascript">  document.write("<div id='div-gpt-ad-Responsive_TSOL_News_SP_ATF_MiniRect'>");  document.write("<scr");  document.write("ipt>");  document.write("cX.callQueue.push(['invoke', function() { ");  document.write("googletag.cmd.push(function() { googletag.display('div-gpt-ad-Responsive_TSOL_News_SP_ATF_MiniRect'); googletag.pubads().refresh([gptAdSlots[15]]); });");    document.write("}]);");  document.write("</scr");  document.write("ipt>");  document.write("</div>");  </script></div></div></div>
#  </div>
#  <!--dynamic-html.blade.php-->
#  <div id="widget-3879">
#  <div class="med-rec" id="newsletterbox" style="overflow: hidden;"><iframe frameborder="0" height="260px" id="ifnewsletter" scrolling="no" style="display:none;" width="100%"></iframe></div><script src="https://cdn.thestar.com.my/Widgets/newsletter/interestNewsletter.js?v=20200902" type="text/javascript"></script><script>function inlineNewsletter() {        if (jQuery('.story > p').length >= 1) {            jQuery('.story > p').each(function (index) {                if (jQuery('.story > p').length >= 5) {                    if (index == 4) {                        jQuery(this).after(jQuery("#ifnewsletter").show());                         return false;                    }                }                else {                    jQuery("#ifnewsletter").hide();                }            });        }        else {            jQuery('.story > br').each(function (index) {                if (jQuery('.story > br').length >= 5) {                    if (index == 4) {                        jQuery(this).after(jQuery("#ifnewsletter").show());                         return false;                    }                }                else {                    jQuery("#ifnewsletter").hide();                }            });        }}if (jQuery('#cx_paywall').length == 0){if( document.getElementById('ifnewsletter').src){inlineNewsletter();}}</script>
#  </div>
#  <!--dynamic-html.blade.php-->
#  <div id="widget-2125">
#  <div class="sponsored-panel" id="divBranded" style="display:none;"></div><script type="text/javascript">var Brand_currentItem = 0;var reqSP = new XMLHttpRequest();reqSP.open('GET', 'https://cdn.thestar.com.my/Components/Branded/Branded.txt' + '?v=' + Date.now(), true);reqSP.send(null);reqSP.onreadystatechange = function (){if(reqSP.readyState == 4 && reqSP.status == 200){if(reqSP.responseText.trim().length > 0 && reqSP.responseText != undefined){$('#divBranded').html(reqSP.response);$('#divBranded').removeAttr('style');}}}</script><script type="text/javascript">function Brand_showItem(n){if (jQuery('.BrandBox.item-' + n).length){jQuery('.BrandBox').hide();jQuery('.BrandBox.item-' + n).show();Brand_currentItem = n;jQuery('#lnkBrandNext').removeClass('disabled');jQuery('#lnkBrandPrev').removeClass('disabled');if (Brand_currentItem == 0){jQuery('#lnkBrandPrev').addClass('disabled');}if (jQuery('.BrandBox.item-' + (n + 1)).length == 0){jQuery('#lnkBrandNext').addClass('disabled');}}}function Brand_nextItem(n){if(Brand_currentItem == undefined){Brand_currentItem = 0;}else{Brand_currentItem = Brand_currentItem + n;}if (Brand_currentItem < 0) {Brand_currentItem = 0;}if (jQuery('.BrandBox.item-' + Brand_currentItem).length == 0){Brand_currentItem = Brand_currentItem - 1;}Brand_showItem(Brand_currentItem);}</script>
#  </div>
#  <!--dynamic-html.blade.php-->
#  <div id="widget-4209">
#  <div class="side-combo-1 voucher" id="iPrice" style="display:block"> <div class="headline"> <h1 class="title-03">Vouchers</h1> </div><div class="form-group"> <label class="control-label col-xs-3 col-sm-3" for="voucher-category">Category</label> <div class="col-xs-9 col-sm-9"> <select class="form-control voucher__select" id="voucher-category" name="voucher-category"> <option value="top-20-vouchers.json">Popular</option> <option value="food-grocery.json">Food &amp; Groceries</option> <option value="fashion.json">Fashion</option> <option value="home-living.json">Home &amp; Living</option> <option value="beauty-health.json">Health &amp; Beauty</option> <option value="kids-toys.json">Children</option> <option value="electronics.json">Tech</option> <option value="finance-investment.json">Finance</option> <option value="e-hailing.json">eHailing</option> <option value="travel.json">Travel</option> <option value="sports-outdoors.json">Sports &amp; Outdoor</option> </select> </div></div><div class="voucher__items"> <div class="voucher__item" style="background:url('https://cdn.thestar.com.my/Themes/img/loading.gif') no-repeat center center;height: 50px;"></div></div><div class="voucher__footer"> <div class="button-view left"><a data-content-title="#" data-content-type="View More" data-list-type="Vouchers Widget" data-list-variant="#" href="#" id="ViewMoreVoucher" target="_blank">View More Vouchers</a></div></div></div><script src="https://cdn.thestar.com.my/Themes/js/iprice.min.js?v=20210224"></script>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="container">
#  <p>Copyright © 1995-
#              <span id="spanCopyright">
#  <script type="text/javascript">
#                      $(document).ready(function () {
#                          var theDate = new Date();
#                          $('#spanCopyright').text(theDate.getFullYear())
#                      })
#                  </script>
#  </span> Star Media Group Berhad (10894D)</p><p>Best viewed on Chrome browsers.</p>
#  </div>,
#  <div class="container">
#  <nav>
#  <ul>
#  <li id="sticky-home">
#  <a data-content-id="https://www.thestar.com.my" data-content-title="Home" data-content-type="Navigation" data-list-type="Bottom Sticky Menu" href="/" onclick="ga('send', 'event', 'TSOL STICKY NAVI', 'Standard', '/Home/');">
#  <div class="mobilenav__icon home"></div>
#                          Home
#                      </a>
#  </li>
#  <li id="sticky-foryou">
#  <a data-content-id="https://www.thestar.com.my/foryou" data-content-title="For You" data-content-type="Navigation" data-list-type="Bottom Sticky Menu" href="/foryou" onclick="ga('send', 'event', 'TSOL STICKY NAVI', 'Standard', '/For You/');">
#  <div class="mobilenav__icon paper"></div>
#                          For You
#                      </a>
#  </li>
#  <li id="sticky-saved-articles">
#  <a data-content-id="https://www.thestar.com.my/saved-articles" data-content-title="Bookmark" data-content-type="Navigation" data-list-type="Bottom Sticky Menu" href="/saved-articles" onclick="ga('send', 'event', 'TSOL STICKY NAVI', 'Standard', '/Saved-Articles/');">
#  <div class="mobilenav__icon bookmark"></div>
#                          Bookmark
#                      </a>
#  </li>
#  <li id="podcast">
#  <div class="audionav__toggle">
#  <div class="mobilenav__icon podcast"></div>
#                          Audio
#                      </div>
#  </li>
#  <li id="searchnav">
#  <div class="searchnav__toggle">
#  <div class="mobilenav__icon search"></div>
#                          Search
#                      </div>
#  </li>
#  </ul>
#  </nav>
#  </div>,
#  <div class="container" id="drop--search--container">
#  <form action="search" id="searchform" method="GET" role="form">
#  <div class="input-group">
#  <input autofocus="" class="form-control" id="qTextBox" name="q" onkeypress="searchKeyPress(event, 'btnSearch' ); " placeholder="What are you looking for?" type="text"/>
#  <div id="qStockCodeHolder">
#  <input id="qStockCodeVal" type="hidden" value=""/>
#  </div>
#  <div class="input-group-btn">
#  <input class="btn btn-default" id="btnSearch" onclick="
#                              if ($.trim($('#qTextBox').val()).length &gt;=3) {
#                                  jQuery('#qTextBox').addClass('loadinggif');
#                                  post('/search/', { q: document.getElementById('qTextBox').value, qsort: 'newest', qrec: '10', qstockcode: document.getElementById('qStockCodeVal').value }, 'get');
#                                  ga('send', 'event', 'TSOL NAVI', 'Extra-Panel', 'Search Button');
#                              }else if($.trim($('#qTextBox').val()).length &gt; 0 &amp;&amp; $.trim($('#qTextBox').val()).length &lt;3){
#                                  jQuery('#qTextBox').removeClass('loadinggif');
#                                  alert('Please enter at least 3 characters for search phrase.');
#                              }else{
#                                  jQuery('#qTextBox').removeClass('loadinggif');
#                                  alert('Please enter a search phrase.');
#                              }
#                              " style="font-weight: bold" type="button" value="Search">
#  <a class="btn btn-default adv-search-link" data-content-id="https://www.thestar.com.my/search/?adv=1" data-content-title="Advance Search" data-content-type="Navigation" data-list-type="Header" href="/search?adv=1" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Extra-Panel' , 'Advance Search' ); " onmousedown="searchAdvanceClick(this,'qTextBox')" style="font-weight: 900"><i class="icon sprite-icon plus"></i>
#  </a>
#  </input></div>
#  </div>
#  </form>
#  </div>]

# %%
# Get the table for COVID19 identified by the div tag and id=table-container 
soup_div = soup.find_all('div',attrs={'id':'table-container'})
soup_div
# Out:
# []

# %% [markdown]
# [ ]
#
# **EMPTY?**
#
# Why?
#
# Something went wrong? Returned webpage assigned to soup is empty? Let's check

# %%
# show soup
# Out:
# <!--default_base.blade.php-->
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>Covid-19: Cases up by 2,875 bringing total to 384,688 (updated daily) | The Star</title>
# <link href="https://cdn.thestar.com.my/Themes/img/favicon.ico" rel="icon" type="image/png"/>
# <!--START: common.blade.php-->
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/><script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:false},ajax:{deny_list:["bam-cell.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={xpid:"VgIEVF9QChADU1hQAAUGUFc=",licenseKey:"ef8b08f3e1",applicationID:"379274163"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(28),s={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,i.indexOf("dev")!==-1&&(s.dev=!0),i.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&o.on("internal-error",function(t){r(t.stack)}),s.dev&&o.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{p?p-=1:i(s||new UncaughtException(t,e,n),!0)}catch(f){try{o("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function i(t,e){var n=e?null:c.now();o("err",[t,n])}var o=t("handle"),a=t(29),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError";if(!c.disabled){var p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(10),t(9),"addEventListener"in window&&t(6),c.xhrWrappable&&t(11),d=!0)}s.on("fn-start",function(t,e,n){d&&(p+=1)}),s.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,i(n))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){o("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){var t=new PerformanceObserver(function(t,e){var n=t.getEntries();s(v,[n])});try{t.observe({entryTypes:["resource"]})}catch(e){}}function i(t){if(s(v,[window.performance.getEntriesByType(w)]),window.performance["c"+l])try{window.performance[h](m,i,!1)}catch(t){}else try{window.performance[h]("webkit"+m,i,!1)}catch(t){}}function o(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var a=t("ee"),s=t("handle"),c=t(10),f=t(9),u=t(5),d=t(19),l="learResourceTimings",p="addEventListener",h="removeEventListener",m="resourcetimingbufferfull",v="bstResource",w="resource",g="-start",y="-end",x="fn"+g,b="fn"+y,E="bstTimer",R="pushState",S=t("loader");if(!S.disabled){S.features.stn=!0,t(8),"addEventListener"in window&&t(6);var O=NREUM.o.EV;a.on(x,function(t,e){var n=t[0];n instanceof O&&(this.bstStart=S.now())}),a.on(b,function(t,e){var n=t[0];n instanceof O&&s("bst",[n,e,this.bstStart,S.now()])}),c.on(x,function(t,e,n){this.bstStart=S.now(),this.bstType=n}),c.on(b,function(t,e){s(E,[e,this.bstStart,S.now(),this.bstType])}),f.on(x,function(){this.bstStart=S.now()}),f.on(b,function(t,e){s(E,[e,this.bstStart,S.now(),"requestAnimationFrame"])}),a.on(R+g,function(t){this.time=S.now(),this.startPath=location.pathname+location.hash}),a.on(R+y,function(t){s("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),u()?(s(v,[window.performance.getEntriesByType("resource")]),r()):p in window.performance&&(window.performance["c"+l]?window.performance[p](m,i,d(!1)):window.performance[p]("webkit"+m,i,d(!1))),document[p]("scroll",o,d(!1)),document[p]("keypress",o,d(!1)),document[p]("click",o,d(!1))}}},{}],5:[function(t,e,n){e.exports=function(){return"PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver}},{}],6:[function(t,e,n){function r(t){for(var e=t;e&&!e.hasOw ...
# <meta content="index,follow" name="ROBOTS"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!--END: common.blade.php-->
# <!--StandardLayout.additionalGlobalHeadHTML-->
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "NewsArticle",
# "headline": "Covid-19: Cases up by 2,875 bringing total to 384,688 (updated daily)",
# "articleSection": "News",
# "creator": ["DIYANA PFORDTEN","RAZAK AHMAD"],
# "thumbnailUrl": "https://apicms.thestar.com.my/uploads/images/2020/03/23/615952.jpg",
# "dateCreated": "2021-04-22T09:30:00.000Z",
# "url": "https://www.thestar.com.my/news/nation/2020/03/23/covid-19-current-situation-in-malaysia-updated-daily",
# "keywords":["\/News\/Nation" , "Covid-19 Watch", "Covid-19 Coronavirus", "Malaysia", "Movement Control Order", "Wuhan", "Coronavirus", "China", "Quarantine", "Outbreak", "Disease", "2019-nCoV", "Covid-19"]
# }
# </script>
# <!--START: article.blade.php test-->
# <!-- Android native install app-->
# <script>
#         if ('serviceWorker' in navigator) {
#           window.addEventListener('load', function() {
#             navigator.serviceWorker.register('/theme_metro/js/sw.js').then(function(registration) {
#               // Registration was successful
#               console.log('ServiceWorker registration successful with scope: ', registration.scope);
#             }, function(err) {
#               // registration failed :(
#               console.log('ServiceWorker registration failed: ', err);
#             });
#           });
#         }
#     </script>
# <link href="/theme_metro/js/manifest.json" rel="manifest"/>
# <meta content="121120175250633" property="fb:app_id"/>
# <meta content="https://www.thestar.com.my/news/nation/2020/03/23/covid-19-current-situation-in-malaysia-updated-daily" property="og:url"/>
# <meta content="Covid-19: Cases up by 2,875 bringing total to 384,688 (updated daily)" property="og:title"/>
# <meta content="Get the latest update in the numbers of Covid-19 in Malaysia and related information here!" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="en_GB" property="og:locale"/>
# <meta content="The Star" property="og:site_name"/>
# <meta content="600" property="og:image:width"/>
# <meta content="315" property="og:image:height"/>
# <meta content="https://apicms.thestar.com.my/uploads/images/2020/03/23/615952.jpg" property="og:image"/>
# <div class="stickyy">
# <div class="installApp" id="installContainer" style="display:none">
# <button id="btnClose" type="button"> × </button>
# <div id="imgBox">
# <img alt="The Star" onclick="false" src="/theme_metro/images/TSOL640x100.png"/>
# </div>
# <button id="btnAdd" type="button"> View </button>
# </div>
# </div>
# <style>
#
#         div.stickyy {
#             background-color: white;
#             position: sticky !important;
#             z-index: 200 !important;
#         }
#
# /*        @media  only screen and (max-width: 767px){
#             a.navbar-brand.brand-mobile {
#                 padding-top: 3px !important;
#                 margin-top: 12px !important;
#             }
#         }    */
#
#         #installContainer {
#             background-color: white;
#             position: initial;
#             display: inline-block;
#         }
#
#         #imgBox {
#             margin-left: 30px;
#         }
#
#         #btnAdd {
#             border: 1px solid #d6d6d6;
#             padding: 1px 8px;
#             text-align: center;
#             text-decoration: none;
#             position:absolute;
#             border-radius: 3px;
#             right:10%;
#             top:30%;
#         }
#
#         #btnClose {
#             position:absolute;
#             background:none;
#             border:none;
#             margin:0;
#             padding:0;
#             left: 3%;
#             top: 10%;
#             font-size: 32px;
#         }
#
#     </style>
# <script>
#
#         if (navigator.userAgent.match(/Android/i)) {
#
#             let deferredPrompt;
#
#             window.addEventListener('beforeinstallprompt', (e) => {
#               e.preventDefault();
#               deferredPrompt = e;
#               //btnAdd.style.display = 'block';
#               document.getElementById("installContainer").classList.remove("installApp");
#               document.getElementById("installContainer").classList.add("showInstall");
#               document.getElementById("installContainer").style.display = "inline";
#               jQuery('div.stickyy').attr("style", "top: 0 !important; padding-bottom: 3px !important;");
#               jQuery('#navbar-main.affix').attr("style", "top: 55px !important;");
#
#               var position = jQuery(window).scrollTop();
#               jQuery(window).scroll(function() {
#                   var scroll = jQuery(window).scrollTop();
#                   if(jQuery('#installContainer').hasClass('showInstall')){
#                         if(scroll > position) {
#                              //when scrolling down
#                              if(jQuery('#navbar-main').hasClass('affix')){
#                                  jQuery('div.stickyy').attr("style", "top: 0 !important; padding-bottom: 3px !important;");
#                                  jQuery('#navbar-main.affix').attr("style", "top: 55px !important;");
#                              }
#                          }
#                          else {
#                              if(jQuery('#navbar-main').hasClass('affix-top')){
#                                  jQuery('div.stickyy').removeAttr("style", "top: 0 !important;");
#                                  jQuery('#navbar-main').removeAttr("style", "top: 55px !important;");
#                              }
#                          }
#                        position = scroll;
#                   }
#               });
#
#             });
#
#             btnAdd.addEventListener('click', (e) => {
#               deferredPrompt.prompt();
#               deferredPrompt.userChoice
#                 .then((choiceResult) => {
#                   if (choiceResult.outcome === 'accepted') {
#                     console.log('User accepted the A2HS prompt');
#                   } else {
#                     console.log('User dismissed the A2HS prompt');
#                   }
#                   deferredPrompt = null;
#                 });
#
#             });
#
#             btnClose.addEventListener('click', function(){
#                document.getElementById('installContainer').style.display = 'none';
#                document.getElementById("installContainer").classList.remove("showInstall");
#                jQuery('#installContainer').addClass('installApp');
#             });
#
#         }
#
#     </script>
# <meta content="Get the latest update in the numbers of Covid-19 in Malaysia and related information here!" name="description"/>
# <meta content="Covid-19 Watch,Covid-19 Coronavirus,Malaysia,Movement Control Order,Wuhan,Coronavirus,China,Quarantine,Outbreak,Disease,2019-nCoV,Covid-19" name="keywords"/>
# <meta content="Covid-19 Watch" name="cXenseParse:smg-keywords"/>
# <meta content="Covid-19 Coronavirus" name="cXenseParse:smg-keywords"/>
# <meta content="Malaysia" name="cXenseParse:smg-keywords"/>
# <meta content="Movement Control Order" name="cXenseParse:smg-keywords"/>
# <meta content="Wuhan" name="cXenseParse:smg-keywords"/>
# <meta content="Coronavirus" name="cXenseParse:smg-keywords"/>
# <meta content="China" name="cXenseParse:smg-keywords"/>
# <meta content="Quarantine" name="cXenseParse:smg-keywords"/>
# <meta content="Outbreak" name="cXenseParse:smg-keywords"/>
# <meta content="Disease" name="cXenseParse:smg-keywords"/>
# <meta content="2019-nCoV" name="cXenseParse:smg-keywords"/>
# <meta content="Covid-19" name="cXenseParse:smg-keywords"/>
# <meta content="bs_covid19" name="cXenseParse:smg-brandsafety"/>
# <meta content="article" name="pageType"/>
# <meta content="https://www.thestar.com.my/news/nation/2020/03/23/covid-19-current-situation-in-malaysia-updated-daily" name="url"/>
# <meta content="2021-04-22 17:30:00" name="datePublished"/>
# <meta content="2021-04-22 17:30:41" name="dateModified"/>
# <meta content="" name="author"/>
# <meta content="en" name="inLanguage"/>
# <meta content="kw0iev9b8ivxk860cvrn" name="cxenseRandom"/>
# <meta content="Article" name="page_type"/>
# <meta content="Article" name="content_type"/>
# <meta content="242573" name="content_id"/>
# <meta content="Covid-19: Cases up by 2,875 bringing total to 384,688 (updated daily)" name="content_title"/>
# <meta content="News/Nation" name="content_category"/>
# <meta content="News/Regional,StarPlus" name="content_category_alt"/>
# <meta content="news/nation" name="cXenseParse:taxonomy"/>
# <meta content="news/regional" name="cXenseParse:taxonomy"/>
# <meta content="starplus" name="cXenseParse:taxonomy"/>
# <meta content="NA" name="content_author"/>
# <meta content="NA" name="content_sp"/>
# <meta content="By DIYANA PFORDTEN and RAZAK AHMAD" name="content_byline"/>
# <meta content="NA" name="content_agency"/>
# <meta content="English" name="content_language"/>
# <meta content="2021-04-22" name="content_date"/>
# <meta content="Covid-19 Watch,Covid-19 Coronavirus,Malaysia,Movement Control Order,Wuhan,Coronavirus,China,Quarantine,Outbreak,Disease,2019-nCoV,Covid-19" name="content_tags"/>
# <meta content="Metered" name="content_tier"/>
# <meta content="Short" name="content_length"/>
# <meta content="false" name="content_exclusive"/>
# <meta content='{"guid": "242573", "byline": "By DIYANA PFORDTEN and RAZAK AHMAD", "summary": "Get the latest update in the numbers of Covid-19 in Malaysia and related information here!", "image_url" :"https://apicms.thestar.com.my/uploads/images/2020/03/23/615952.jpg","contain_video": false,"is_premium": false,"is_print": false,"access_type": "metered" ,"kicker_name": "Nation","kicker_url": "/news/nation/" } ' name="parsely-metadata"/>
# <meta content="https://apicms.thestar.com.my/uploads/images/2020/03/23/615952.jpg" name="thumbnailUrl"/>
# <meta content="By DIYANA PFORDTEN and RAZAK AHMAD" property="cXenseParse:author"/>
# <meta content="article" name="cXenseParse:pageclass"/>
# <meta content="metered" name="cXenseParse:smg-accesstype"/>
# <meta content="2021-04-22T17:30:00+0800" name="cXenseParse:recs:publishtime"/>
# <meta content="2021-04-22T17:30:41+0800" property="article:modified_time"/>
# <meta content="242573" name="cXenseParse:articleid"/>
# <meta content="Article" name="cXenseParse:smg-contenttype"/>
# <meta content="Nation" name="cXenseParse:kicker_name"/>
# <meta content="/news/nation/" name="cXenseParse:kicker_url"/>
# <meta content="false" name="cXenseParse:is_print"/>
# <meta content="false" name="cXenseParse:is_exclusive"/>
# <meta content="2021-04-22T17:30:00.000Z" property="article:published_time"/>
# <meta content="2021-04-22T17:30:41.000Z" property="article:modified_time"/>
# <meta content="" property="article:author"/>
# <meta content="News" property="article:section"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Covid-19: Cases up by 2,875 bringing total to 384,688 (updated daily)" name="twitter:title"/>
# <meta content="Get the latest update in the numbers of Covid-19 in Malaysia and related information here!" name="twitter:description"/>
# <meta content="https://apicms.thestar.com.my/uploads/images/2020/03/23/615952.jpg" name="twitter:image"/>
# <meta content="3109498" itemprop="identifier"/>
# <meta content="Covid-19: Cases up by 2,875 bringing total to 384,688 (updated daily)" itemprop="headline"/>
# <meta content="article" itemprop="pageType"/>
# <meta content="News" itemprop="articleSection"/>
# <meta content="2021-04-22 17:30:00" itemprop="datePublished"/>
# <meta content="2021-04-22 17:30:41" itemprop="dateModified"/>
# <meta content="https://apicms.thestar.com.my/uploads/images/2020/03/23/615952.jpg" itemprop="image"/>
# <meta content="News" name="article_section_name"/>
# <meta content="NA" name="content_sentiment"/>
# <meta content="NA" name="content_sentiment_magnitude"/>
# <meta content="NA" name="content_classification_main"/>
# <meta content="NA" name="content_classification_main_alt"/>
# <meta content="NA" name="content_classification"/>
# <meta content="NA" name="content_classification_alt"/>
# <link href="https://www.thestar.com.my/news/nation/2020/03/23/covid-19-current-situation-in-malaysia-updated-daily" rel="canonical"/>
# <!--END: article.blade.php-->
# <!-- CSRF Token -->
# <meta content="bHorhpp0AOGiO4AUE233BsyDjXbhlLnnwGuMsfXt" name="csrf-token"/>
# <!-- Global Header scripts -->
# <!-- Start Header Script -->
# <!-- Anti-flicker snippet (recommended)  -->
# <style>.async-hide { opacity: 0 !important} </style>
# <script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
# h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
# (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
# })(window,document.documentElement,'async-hide','dataLayer',4000,
# {'GTM-PVM4TH':true});</script>
# <meta content="app-id=428184176" name="apple-itunes-app"/>
# <link href="https://cdn.thestar.com.my/Themes/css/bootstrap.min.css" rel="stylesheet" type="text/css">
# <link href="https://fonts.googleapis.com/css?family=Lato:300,300i,400,400i,700,700i,900,900i&amp;display=swap" rel="stylesheet" type="text/css">
# <link href="https://cdn.thestar.com.my/Themes/css/tsol2019_pw.css?v=20210907" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/story2017.min.css?v=20211012" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/info.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/bookmark.min.css?v=20201123" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/main.css?v=20210323" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/promo.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/responsive.min.css" media="only screen and (max-width:767px)" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/stock.search.min.css" rel="stylesheet" type="text/css">
# <link href="https://cdn.thestar.com.my/Themes/css/font-awesome.min.css" rel="stylesheet" type="text/css">
# <link href="https://cdn.thestar.com.my/GlobalBar/css/global-bar.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Components/Audio/audio.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/owl.carousel.min.css" rel="stylesheet" type="text/css">
# <link href="https://cdn.thestar.com.my/Themes/css/style.min.css?v=20201123" rel="stylesheet" type="text/css"/>
# <!-- hide globalbar for tablet -->
# <style>@media screen and (min-width: 768px) and (max-width: 1024px){
# #thestar-global-bar { display: none; }
# body { padding-top: 0 !important; }
# #navbar-main.affix { top: 0 !important; }
# }</style>
# <style>
# .sassize{--breakpoint:desktop}@media all and (max-width:991px){.sassize{--breakpoint:tablet}}@media all and (max-width:767px){.sassize{--breakpoint:mobile}}
# img[src$="default.gif"] { display: none;}
# img[src^="https://content.thestar.com.my/smg/settag/name=lotame/tags="] {display:none;}
# .masthead {
#   background: url(https://cdn.thestar.com.my/Widgets/Masthead/2021/diwali.png) no-repeat 0 0 transparent;
# }
# .masthead-2 {
#     position: absolute;
#     width: 250px;
#     left: 41%;
#     right: 41%;
#     top: 12px;
# }
# .anniv-special{
# 	display:none;
# }
# @media only screen and (max-width: 991px) {
#     /*50 years special*/
#     .anniv-special{
# 	display:block;
# 	margin:0 auto;
# 	text-align:center;
#     }
#    .anniv-special img{
#         height: auto;
#         width: 200px;
#         margin-top: 12px;
#         margin-bottom: 12px;
#     }
# }
# </style>
# <script async="" src="https://scdn.cxense.com/cx.cce.js" type="text/javascript"></script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/parsely-onload.min.js"></script>
# <!-- HTML5 Shim and Respond.js IE8 support of HTML5 elements and media queries -->
# <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
# <!--[if lt IE 9]>
# <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
# <script src="https://oss.maxcdn.com/libs/respond.js/1.4.2/respond.min.js"></script>
# <![endif]-->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/URI.js/1.18.10/URI.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/postscribe/2.0.8/postscribe.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/js.cookie.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/jquery.dotdotdot.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/vue@2.5.12/dist/vue.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/axios/0.19.0/axios.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/Main.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/widget_mixin.js"></script>
# <script>var my_jquery = jQuery;</script>
# <script>jQuery = my_jquery;</script>
# <script type="text/javascript">
# var pageType = jQuery('meta[name=pageType]').attr("content");
# if(pageType == "article"){
# var cX = window.cX = window.cX || {}; cX.callQueue = cX.callQueue || [];
# var cxenseRandom = jQuery('meta[name=cxenseRandom]').attr("content");
# cX.CCE = cX.CCE || {}; cX.CCE.callQueue = cX.CCE.callQueue || [];
# }
# else{ var cX = cX || {}; cX.callQueue = cX.callQueue || []; }
# </script>
# <script src="https://cdn.thestar.com.my/Themes/js/slick.min.js"></script>
# <script defer="" src="https://cdn.thestar.com.my/Themes/js/jquery.unveil.js" type="text/javascript"></script>
# <script src="//connect.facebook.net/en_US/all.js" type="text/javascript"></script>
# <script>
# FB.init({
#   appId: '388467334571811',
#   version: 'v2.9',
#   status: true, // check login status
#   cookie: true, // enable cookies to allow the server to access the session
#   xfbml: true  // parse XFBML
# });
#
# var KICKER_FREE_MARKUP='<span class="labels labels--free" data-toggle="tooltip" title="" data-original-title="This is a Free article"><i class="fa fa-unlock"></i></span>'
# var KICKER_PREMIUM_MARKUP='<span class="biz-icon" data-toggle="tooltip" title="" id="sbp-tip" data-original-title="Premium">Premium</span>';
# var KICKER_LOCK_MARKUP='<span class="biz-icon" data-toggle="tooltip" title="" id="sbp-tip" data-original-title="To unlock the article, click on the headline and log in with your StarBiz Premium account or select a membership to join." aria-describedby="tooltip489695">StarBiz Premium</span>';
# var KICKER_UNLOCK_MARKUP='<span class="biz-icon"><i class="fa fa-unlock"></i></span>';
# </script>
# <!-- Cx FB user linking script begin -->
# <script type="text/javascript">
#   cX.callQueue.push(['invoke', function() {
#     function checkFBLogin() {
#      if (window.FB && typeof FB.getLoginStatus === 'function') {
#
#         FB.getLoginStatus(function(response) {
#           if (response.status === 'connected') {
#             // Read the FaceBook user ID
#             var fbUserId = response.authResponse.userID;
#             // Map the Facebook user ID to the Cxense user ID
#             var persistedQueryId = '925dff57b9697543df967d4cbe9a38a074458905';
#             var apiUrl = 'https://api.cxense.com/profile/user/external/link/update?callback={{callback}}'
#               + '&persisted=' + encodeURIComponent(persistedQueryId)
#               + '&json=' + encodeURIComponent(cX.JSON.stringify({ id: fbUserId, cxid: cX.getUserId() }));
#             cX.jsonpRequest(apiUrl, function (data) { /* If wanted, verify success here*/ });
#           } else {
#             setTimeout(checkFBLogin, 1000);
#           }
#         });
#
#       } else {
#         setTimeout(checkFBLogin, 1000);
#       }
#     }
#     checkFBLogin();
#   }]);
# </script>
# <!-- Cx FB user linking script end -->
# <script src="https://cdn.thestar.com.my/Themes/js/owl.carousel.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/parsely-onload.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/mediatag.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/mediahelper.min.js"></script>
# <link href="https://cdn.thestar.com.my/Themes/img/touch-icon-precomposed.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://cdn.thestar.com.my/Themes/img/touch-icon-iphone.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://cdn.thestar.com.my/Themes/img/touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://cdn.thestar.com.my/Themes/img/touch-icon-ipad.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://cdn.thestar.com.my/Themes/img/touch-icon-iphone-retina.png" rel="apple-touch-icon" sizes="167x167"/>
# <link href="https://cdn.thestar.com.my/Themes/img/touch-icon-ipad-retina.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://cdn.thestar.com.my/Themes/img/touch-icon-192x192.png" rel="apple-touch-icon" sizes="192x192"/>
# <link href="https://cdn.thestar.com.my/Themes/css/widgettop.min.css" rel="stylesheet" type="text/css">
# <script src="https://cdn.thestar.com.my/Themes/js/widgettop.min.js"></script>
# <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5dfaeb0face4ad17" type="text/javascript"></script>
# <script data-obct="" type="text/javascript">
#     /** DO NOT MODIFY THIS CODE**/
#     !function(_window, _document) {
#       var OB_ADV_ID='00a149fe9401c432f57edaa96ee66b065d';
#       if (_window.obApi) {var toArray = function(object) {return Object.prototype.toString.call(object) === '[object Array]' ? object : [object];};_window.obApi.marketerId = toArray(_window.obApi.marketerId).concat(toArray(OB_ADV_ID));return;}
#       var api = _window.obApi = function() {api.dispatch ? api.dispatch.apply(api, arguments) : api.queue.push(arguments);};api.version = '1.1';api.loaded = true;api.marketerId = OB_ADV_ID;api.queue = [];var tag = _document.createElement('script');tag.async = true;tag.src = '//amplify.outbrain.com/cp/obtp.js';tag.type = 'text/javascript';var script = _document.getElementsByTagName('script')[0];script.parentNode.insertBefore(tag, script);}(window, document);
# obApi('track', 'PAGE_VIEW');
# </script>
# <noscript><img src="//amplifypixel.outbrain.com/pixel?mid=00a149fe9401c432f57edaa96ee66b065d"/></noscript>
# <!-- Start Deco masthead -->
# <script type="text/javascript">
# jQuery(document).ready(function(){
# var checkDeco = new Date();
# var decoStart = new Date("November 1, 2021 00:00:00");
# var decoEnd = new Date("November 7, 2021 23:59:59");
# if (checkDeco.getTime() > decoStart.getTime() && checkDeco.getTime() < decoEnd.getTime()){
# //This is for regular festival masthead
# $("#page-header > div >div").attr("class", "container masthead");
#
# }
# });
# </script>
# <!-- End Deco masthead -->
# <script>var rmad = false;</script>
# <!-- End Header Script --> <!-- theme includes js_extra.blade.php -->
# <script type="text/javascript">
# var viewid = Math.round(Math.random() * 100000000000);
# function sasiajserver(size,position){
# var SAS = JSON.parse(jQuery('meta[name=SAS]').attr("content"));
# var rdm2 = Math.round(Math.random() * 100000000000);
# return "https://content.thestar.com.my/smg/jserver/viewid=" + viewid +
#     "/random=" + rdm2 +
#     "/network=SMG/site=TSOL" +
#     "/area=" + SAS.area +
#     "/pagetype=" + SAS.pagetype +
#     "/platform=" + sascalcsize() +
#     "/size=" + size +
#     "/position=" + position;
# }
# function sascalcsize(){var b=window.getComputedStyle(document.querySelector(".sassize"));var a=b.getPropertyValue("--breakpoint");return a};
# </script>
# <!-- Admiral -->
# <script>
#     window.admiral = window.admiral || function() {(admiral.q = admiral.q || []).push(arguments)};
#              window.admiral("targeting", "set", "MyStarMember", "false");
#          if(pageType == "article"){
#                 var daxsubscriber = false;
#           }
#
#     if(pageType == "article"){
#         window.admiral("after", "measure.detected", function(user) {
#
#         let eventLabel;
#
#         if (user.adblocking) {
#
#           eventLabel = "blocked";
#
#         }
#
#         if (user.whitelisted) {
#
#           eventLabel = "whitelisted";
#
#         }
#
#
#
#         if (eventLabel) {
#
#           ga("send", "event", "Admiral", "pageview", eventLabel, {
#
#             nonInteraction: true
#
#           });
#
#             }
#
#         });
#     }
# </script>
# <!-- End Admiral -->
# <script>
# // show or hide login button
# var rmad = false;
# var isLogin = false;
#
# tkValid = [false,false];
# if (tkValid[0] === true) {
#     rmad = tkValid[1];
#     isLogin = true;
# } else {
#     isLogin = false;
# }
#
# jQuery(document).ready(function() {
#   if (tkValid[0] === true) {
#     jQuery('.btn_login').hide();
#     jQuery('.login_menu').show();
#     jQuery('.m-login-menu').show();
#     jQuery('.m-login-button').attr("style", "display: none !important"); // Override css
# } else {
#     jQuery('.btn_login').show();
#     jQuery('.login_menu').hide();
#     jQuery('.m-login-button').show();
#     jQuery('.m-login-menu').hide();
# }
# });
# </script> <!-- resources common css_includes.blade.php -->
# <!-- theme includes css_includes.blade.php --> <!-- Widget CSS links -->
# <link href="/theme_metro/widgets/article-details/article-details.css" rel="stylesheet" type="text/css">
# <!-- Page Header scripts -->
# <link href="https://cdn.thestar.com.my/Themes/css/print_v2.css" rel="stylesheet" type="text/css"/>
# <script defer="" src="https://cdn.thestar.com.my/Themes/js/story.min.js?v=20210825" type="text/javascript"></script>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script async="" src="//cdn.thestar.com.my/Themes/js/prebid.js"></script>
# <script async="" charset="utf-8" src="https://platform.twitter.com/widgets.js"></script>
# <script>
# if (!rmad) {
#   var sectionName = $('meta[name=article_section_name]').attr("content");
#   document.write('<scr');
#   document.write('ipt src="https://cdn.thestar.com.my/Themes/js/gpt/' + sectionName + 'Story.js?v=20211001">');
#   document.write("</scr");
#   document.write("ipt>");
# }
# </script>
# <script src="/theme_metro/js/trendingParsely.js" type="text/javascript"></script>
# <script>
# (function(w,d,s,u,n,i,f,g,e,c){w.WDMObject=n;w[n]=w[n]||function(){(w[n].q=w[n].q||[]).push(arguments);};w[n].l=1*new Date();w[n].i=i;w[n].f=f;w[n].g=g;e=d.createElement(s);e.async=1;e.src=u;c=d.getElementsByTagName(s)[0];c.parentNode.insertBefore(e,c);})(window,document,"script","//api.dmcdn.net/pxl/cpe/client.min.js","cpe","5f64733dfc2346192550c7a5",{autonext_enable:false})
# </script>
# <!-- Start of Survicate (www.survicate.com) code -->
# <script type="text/javascript">
#   (function (w) {
#     var s = document.createElement('script');
#     s.src = '//survey.survicate.com/workspaces/40636b6a623c41a574580c19efa630b6/web_surveys.js';
#     s.async = true;
#     var e = document.getElementsByTagName('script')[0];
#     e.parentNode.insertBefore(s, e);
#   })(window);
# </script>
# <!-- End of Survicate code -->
# <!-- Admiral script -->
# <script>
# window.admiral("targeting", "set", "pageClass", "article");
# </script>
# <!-- End Admiral script -->
# <script>
#         window.Laravel = {"csrfToken":"bHorhpp0AOGiO4AUE233BsyDjXbhlLnnwGuMsfXt"}
#         var IMAGE_URL = 'https://apicms.thestar.com.my/';
#     </script>
# </link></link></link></link></link></link></link></head>
# <body>
# <div class="sassize"></div>
# <!-- Main THEME Content -->
# <!-- page content -->
# <div class="widgettop" id="widgettop" style="display:none;">
# <div class="flex-container">
# <div class="firinfo"></div>
# <div class="close">
# <img id="closeButton" src="https://cdn.thestar.com.my/Themes/img/close.png"/>
# </div>
# </div>
# </div> <!-- HEADER OF THEME -->
# <!-- header_menu -->
# <style type="text/css">
#   @media  screen and (max-width: 768px){
#     a#hllogin:hover {
#       background-color: #EEEEEE !important;
#     }
#   }
#   .navbar-header{
#       margin-right: 0 !important;
#   }
# </style>
# <header id="page-header">
# <div class="branding">
# <div class="container">
# <a class="navbar-brand brand-prime" data-content-id="https://www.thestar.com.my" data-content-title="The Star Online" data-content-type="Navigation" data-list-type="Header" href="/">
# <svg aria-label="the star online" class="icon" height="55" role="img" width="164">
# <image border="0" height="55" src="https://cdn.thestar.com.my/Themes/img/logo-tsol-logo.png" width="164" xlink:href="https://cdn.thestar.com.my/Themes/img/logo-tsol-full.svg"/>
# </svg>
# </a>
# <ul class="nav social-branding right">
# <!--                <li>
#                     <a href="https://newsstand.thestar.com.my/epaper/" target="_blank" class="epaper"
#                        data-list-type="Header"
#                        data-content-type="App Download"
#                        data-content-title="ePaper"
#                        data-content-id="https://newsstand.thestar.com.my/epaper/ ">
#                         <i class="icon sprite-icon"></i> The Star ePaper
#                     </a>
#                 </li>-->
# <li class="dropdown dropdown--subscribe top-bar">
# <a class="btn--subscribe" data-content-id="https://www.thestar.com.my/subscription" data-content-title="Subscription" data-content-type="Navigation" data-list-type="Header" href="/subscription">Subscriptions</a>
# </li>
# <li class="btn-login" id="btn_login">
# <a class="login" data-content-id="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=" data-content-title="Log In" data-content-type="Outbound Referral" data-list-type="Header" href="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=">
#                         Log In
#                      </a>
# </li>
# <li class="dropdown top-bar" id="login_menu" style="display:none;">
# <a class="log-in-light" id="hllogin"><i class="icon sprite-icon"></i></a>
# <ul class="dropdown-menu log-in 123">
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/profile.aspx" data-content-type="Manage Profile" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/profile.aspx" target="_blank">Manage Profile
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/changepassword.aspx" data-content-type="Change Password" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/changepassword.aspx" target="_blank">Change Password
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/sessions.aspx" data-content-type="Manage Logins" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/sessions.aspx" target="_blank">Manage Logins
#                                 </a>
# </li>
# <li style="border-top:1px solid #d6d6d6">
# <a data-content-title="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" data-content-type="Manage Subscription" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" target="_blank">Manage Subscription
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/transhistory.aspx" data-content-type="Transaction History" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/transhistory.aspx" target="_blank">Transaction History
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/billing.aspx" data-content-type="Manage Billing Info" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/billing.aspx" target="_blank">Manage Billing Info
#                                 </a>
# </li>
# <li style="border-top:1px solid #d6d6d6">
# <a data-content-title="https://www.thestar.com.my/foryou/edit" data-content-type="Manage For You" data-list-type="Profile Management" href="https://www.thestar.com.my/foryou/edit">Manage For You
#                                 </a>
# </li>
# <li style="border-bottom:1px solid #d6d6d6">
# <a data-content-title="https://www.thestar.com.my/saved-articles" data-content-type="Manage Bookmarks" data-list-type="Profile Management" href="https://www.thestar.com.my/saved-articles">Manage Bookmarks
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://www.thestar.com.my/subscribe" data-content-type="Package &amp; Pricing" data-list-type="Profile Management" href="https://www.thestar.com.my/subscribe">Package &amp; Pricing
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://www.thestar.com.my/faqs/" data-content-type="FAQs" data-list-type="Profile Management" href="https://www.thestar.com.my/faqs/">FAQs
#                                 </a>
# </li>
# <li class="log-out">
# <a data-content-title="https://www.thestar.com.my" data-content-type="Log Out" data-list-type="Profile Management" href="#" onclick="logout();">Log Out
#                                 </a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <nav class="navbar navbar-custom" data-offset-top="197" data-spy="affix" id="navbar-main">
# <div class="container">
# <div class="navbar-header">
# <button class="navbar-toggle left" data-target="#tsolmobar" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <i class="icon-x fa fa-times"></i>
# </button>
# <a class="navbar-brand brand-mobile left" data-content-id="https://www.thestar.com.my" data-content-title="The Star Online" data-content-type="Navigation" data-list-type="Header" href="/">
# <svg aria-label="the star online" class="icon" height="26" role="img" width="70">
# <image border="0" height="26" src="https://cdn.thestar.com.my/Themes/img/logo-tsol-mobile.png" width="70" xlink:href="https://cdn.thestar.com.my/Themes/img/logo-tsol-full.svg" xmlns:xlink="http://www.w3.org/1999/xlink"/>
# </svg>
# </a>
# </div>
# <div id="tsolnavbar">
# <ul class="nav navbar-nav navbar-left">
# <li class="show-sd">
# <button aria-expanded="false" class="mega-nav-toggle navbar-toggle collapsed hidden-xs" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <i class="icon-x fa fa-times"></i>
# </button>
# </li>
# <li>
# <a class="home-light" data-content-id="https://www.thestar.com.my" data-content-title="Home" data-content-type="Navigation" data-list-type="Header" href="/" id="navi-home" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Home/' ); " target="">
# <i class="icon sprite-icon"></i>
# </a>
# </li>
# <li class="dropdown">
# <a class="starplus" data-content-id="https://www.thestar.com.my/starplus" data-content-title="StarPlus" data-content-type="Navigation" data-list-type="Header" href="/starplus" id="navi-starplus" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/StarPlus/' ); " target="">
#                     StarPlus
#                     </a>
# </li>
# <li class="dropdown">
# <a class="news" data-content-id="https://www.thestar.com.my/news" data-content-title="News" data-content-type="Navigation" data-list-type="Header" href="/news" id="navi-news" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/News/' ); " target="">
#                     News
#                     </a>
# </li>
# <li class="dropdown">
# <a class="asean+" data-content-id="https://www.thestar.com.my/aseanplus" data-content-title="Asean+" data-content-type="Navigation" data-list-type="Header" href="/aseanplus" id="navi-asean+" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/AseanPlus/' ); " target="">
#                     Asean+
#                     </a>
# </li>
# <li class="dropdown">
# <a class="business" data-content-id="https://www.thestar.com.my/business" data-content-title="Business" data-content-type="Navigation" data-list-type="Header" href="/business" id="navi-business" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Business/' ); " target="">
#                     Business
#                     </a>
# </li>
# <li class="dropdown">
# <a class="sport" data-content-id="https://www.thestar.com.my/sport" data-content-title="Sport" data-content-type="Navigation" data-list-type="Header" href="/sport" id="navi-sport" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Sport/' ); " target="">
#                     Sport
#                     </a>
# </li>
# <li class="dropdown">
# <a class="metro" data-content-id="https://www.thestar.com.my/metro" data-content-title="Metro" data-content-type="Navigation" data-list-type="Header" href="/metro" id="navi-metro" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Metro/' ); " target="">
#                     Metro
#                     </a>
# </li>
# <li class="dropdown">
# <a class="lifestyle" data-content-id="https://www.thestar.com.my/lifestyle" data-content-title="Lifestyle" data-content-type="Navigation" data-list-type="Header" href="/lifestyle" id="navi-lifestyle" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Lifestyle/' ); " target="">
#                     Lifestyle
#                     </a>
# </li>
# <li class="dropdown">
# <a class="food" data-content-id="https://www.thestar.com.my/food" data-content-title="Food" data-content-type="Navigation" data-list-type="Header" href="/food" id="navi-food" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Food/' ); " target="">
#                     Food
#                     </a>
# </li>
# <li class="dropdown">
# <a class="tech" data-content-id="https://www.thestar.com.my/tech" data-content-title="Tech" data-content-type="Navigation" data-list-type="Header" href="/tech" id="navi-tech" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Tech/' ); " target="">
#                     Tech
#                     </a>
# </li>
# <li class="dropdown">
# <a class="education" data-content-id="https://www.thestar.com.my/education" data-content-title="Education" data-content-type="Navigation" data-list-type="Header" href="/education" id="navi-education" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Education/' ); " target="">
#                     Education
#                     </a>
# </li>
# <li class="dropdown">
# <a class="opinion" data-content-id="https://www.thestar.com.my/opinion" data-content-title="Opinion" data-content-type="Navigation" data-list-type="Header" href="/opinion" id="navi-opinion" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Opinion/' ); " target="">
#                     Opinion
#                     </a>
# </li>
# <li class="dropdown">
# <a class="videos" data-content-id="https://www.thestartv.com/c/news" data-content-title="Videos" data-content-type="Outbound Referral" data-list-type="Header" href="https://www.thestartv.com/c/news" id="navi-videos" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , 'https://www.thestartv.com/c/news' ); " style="" target="_blank">
#                     Videos
#                     </a>
# </li>
# <li class="dropdown">
# <a class="photos" data-content-id="https://www.thestar.com.my/photos" data-content-title="Photos" data-content-type="Navigation" data-list-type="Header" href="/photos" id="navi-photos" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Photos/' ); " target="">
#                     Photos
#                     </a>
# </li>
# <li class="dropdown">
# <a class="starpicks" data-content-id="https://www.thestar.com.my/starpicks" data-content-title="StarPicks" data-content-type="Navigation" data-list-type="Header" href="/starpicks" id="navi-starpicks" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Starpicks/' ); " target="">
#                     StarPicks
#                     </a>
# </li>
# </ul>
# </div>
# <ul class="nav navbar-nav navbar-right">
# <li class="hidden-lg dropdown dropdown--subscribe">
# <a aria-expanded="false" class="btn--subscribe dropdown-toggle" data-prokeyscachednode="false" onclick="toggleSubDrop()" role="button">Subscriptions</a>
# <ul class="dropdown-menu" id="subDrop" style="display: none;">
# <li>
# <a data-content-id="https://www.thestar.com.my/subscribe" data-content-title="The Star Digital Access" data-content-type="Navigation" data-list-type="Header" href="/subscribe">The Star Digital Access</a>
# </li>
# <li>
# <a data-content-id="https://newsstand.thestar.com.my/" data-content-title="Newsstand" data-content-type="Outbound Referral" data-list-type="Header" href="https://newsstand.thestar.com.my/">Newsstand</a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/sms-services" data-content-title="SMS Services" data-content-type="Navigation" data-list-type="Header" href="/sms-services">SMS Services</a>
# </li>
# </ul>
# </li>
# <li class="m-login-button hidden-md hidden-lg" id="btn_login" style="display: none;">
# <a class="login bttn bttn--log" data-content-id="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=" data-content-title="Log In" data-content-type="Outbound Referral" data-list-type="Header" href="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=">Log In
#                     </a>
# </li>
# <li class="m-login-menu hidden-md hidden-lg" id="login_menu" style="display:none;">
# <a class="log-in" id="hllogin" onclick="toggleDrop()"><i class="icon sprite-icon"></i></a>
# <ul class="dropdown-menu log-in" id="loginDrop" style="display: none;">
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/profile.aspx" data-content-type="Manage Profile" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/profile.aspx" target="_blank">Manage Profile
#                             </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/changepassword.aspx" data-content-type="Change Password" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/changepassword.aspx" target="_blank">Change Password
#                             </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/sessions.aspx" data-content-type="Manage Logins" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/sessions.aspx" target="_blank">Manage Logins
#                             </a>
# </li>
# <li style="border-top:1px solid #d6d6d6">
# <a data-content-title="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" data-content-type="Manage Subscription" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" target="_blank">Manage Subscription
#                             </a>
# </li>
# <li>
# ...
#   {{item['V2 Header']}}
# <!--% } %-->
# </p></a>
# <!--%
# }
# }
# %--></div>
# </div><!--slidebox-wrapper-->
# </div><!--promo-box-->
# </div>
# <script id="CCERenderSticky" type="text/javascript">
#                     // result from /public/widget/data wrapped in  {"response":{} }
#                     window['cx_widgetDataFooter'] = { "response": {"items":[{"V2 Header":"Subscribe Now!","description":"<b>Read<\/b> unlimited content without advertisements with our Premium Plan. Subscribe Now!","V1 Header":"Read","url":"https:\/\/www.thestar.com.my\/subscribe","V1 Body":"unlimited content without advertisements with our Premium Plan.","buttonleft":"Subscribe","templateName":"Generic Article Message Template","templateDescription":"Generic Article Message Template","offerProductId":"8nemxqativil","header":"Read unlimited content without advertisements with our Premium Plan. Subscirbe now!","campaign":"34","testId":"4","click_url":"https:\/\/api.cxense.com\/public\/widget\/click\/AKV8Yhul3Vw6R_YdKt6oD1f0dD4ai5oTr_PhvlTipGk6F9CPhTLMLTB3wE43Kiz6g7o39I-7OLv0pno8rtM-OWyODCmacM71dKRyY1tQ5Jzf9GABXq-U6cfQ5jDsht85pS_Nc6wwGNlYCXU3V7CU8mv5wOj9FAKQ8u7MOtqVDaNquKFKRoZKtD7onDA08UjyTZptqgXJ5Jw841WgGUMbkiZjUwXadWPwQrwMGcTNOokpxT-fo302E3VCUcJaLlp1J1XFPSuc9yLYqJZM40arDeL2oRMECDwrHWoBMFPIDqB3UFEJ6XkYJ29Lwfopkxr7q14YgPU3P0FrGoZGzimzDDdihzg-AMnp2Uhnem2JOjhqUpC3ikNdOV4xx27_d0_TpuWJ02kxWoUJ5KtppSdseIeL2UnVN15X-0qkRsj5mDBVoqt6g6OQ61YUHR_ij2Bj_tkLwq5h2ZAx4YyMMzWqYt_REUiy9zwYAW8VQcnR0TXG0tbUY8TakK3H-7tPgPqKKFSWrMsMIXGw0MVr1sml-5X6IbfHzizDMUYETPkkUf3SXSCirIhdHxivRDuQDITxkAEXPVVLV74UMTJ3UW1jvXhuk9X1g-Qz0ePby42xI4k7raM4S8L2xcfFkvYA5wQFUHhVhWA0"}],"template":"<!--%\nvar items = data.response.items;\nfor (var i = 0; i < items.length; i++) {\n    var item = items[i];\n%-->\n<!--% if (item.campaign != 1) { %-->\n<a class=\"f14\" tmp:id=\"{{cX.CCE.clickTracker(item)}}\" tmp:href=\"{{item.url}}\">\n<p style=\"text-align:center;\">{{item['V1 Header']}}\n  &nbsp;{{item['V1 Body']}}\n <!--% if (item.campaign != 17 && item.campaign != 19) { %-->\n &nbsp;{{item['V2 Header']}}\n<!--% } %-->\n<\/p><\/a>\n<!--%\n}\n}\n%-->","prnd":"kw0iaylk5g16thcurcte"} };
#                     window['CCEAPIRequestFooter'] = { "request": {"json":{"context":{"referrer":"https:\/\/t.co\/","url":"https:\/\/www.thestar.com.my\/news\/nation\/2021\/11\/15\/039timah-dolah-wahab-whatever039-still-a-no-from-pas-despite-cabinet-nod-for-homegrown-whiskey-brand","categories":{"usertype":"anonymous web"},"parameters":[{"key":"usertype","value":"anonymous web"}]},"widgetId":"4e4f71fba5ec6f497e11d1a90c1078c143b0aed4","user":{"ids":{"usi":"ka0wfaja29d7ojou"}},"prnd":"kw0iaylk5g16thcurcte"}} };
#
#                     let isCCEDownFooter = false;
#                     let CCEErrorFooter = window['cx_widgetDataFooter'].response;
#                     if (CCEErrorFooter === '5xx' || CCEErrorFooter === 'timeout' || CCEErrorFooter === '4xx' || CCEErrorFooter === 'requesttimeout') {
#                        isCCEDownFooter = true;
#                        delete window['cx_widgetDataFooter'];
#                     }
#
#                     $(window).on("load", function() {
# 						// render result if available
# 						if (window['cx_widgetDataFooter']) {
# 							cX.CCE.render('cx_sticky', window['cx_widgetDataFooter']);
# 						}
#                         if (window['cx_widgetDataFooter'] && window['cx_widgetDataFooter'].response.items && parseInt(window['cx_widgetDataFooter'].response.items[0].campaign) !== 1) {
#                             loadsticky();
#                         }
#                         else if (isCCEDownFooter) {
#                             console.error(CCEErrorFooter);
#                             let html = `
#                                 <div id="cx_sticky_footer_ccedown">
#                                     <a class="f14" href="https://www.thestar.com.my/subscribe/?p=trial">
#                                         <p style="text-align:center;">Start your &nbsp;<span style="background-color:#000;color:#fff; font-weight:700; font-size:16px;padding:2px 4px;">FREE</span> &nbsp;trial today for unlimited access to content and features.</p>
#                                     </a>
#                                 </div>
#                            `;
#                            $('#cx_sticky').after(html);
#                            $('#promobox').show();
#                         }
#                     });
#                 </script>
# <script type="text/javascript">
# cX.CCE = cX.CCE || {}; cX.CCE.callQueue = cX.CCE.callQueue || [];
# $(document).ready(function() {
#     var sticky = $('#promobox');
#
#     $("#promobox a.close").click(function () {
#         sticky.css({'right':'-1903px'});
#         sticky.fadeOut('slow');
#         setCookie('promobox', '1');
#     });
# });
# function loadsticky(){
#
#     var showPromo = 1;
#     var i, x, y, ARRcookies = document.cookie.split(";")
#     for (i = 0; i < ARRcookies.length; i++) {
#         x = ARRcookies[i].substr(0, ARRcookies[i].indexOf("="))
#         y = ARRcookies[i].substr(ARRcookies[i].indexOf("=") + 1)
#         x = x.replace(/^\s+|\s+$/g, "")
#         if (x == "promobox")
#             showPromo = 0;
#     }
#
#     if(showPromo == 1){
#         $('#promobox').show();
#         $("#cx_sticky").removeAttr("style");
#     }
# }
# function setCookie(name, value) {
#     //set 1 day 24*60*60
#     value = encodeURI(value) + '; max-age=3600'
#     document.cookie = name + '=' + value + '; path=/;'
# }
# </script>
# </div>
# <!-- /page content -->
# <!-- Global Footer scripts -->
# <!-- Start Footer Script -->
# <input id="hfldUrl" name="hfldUrl" type="hidden" value="HNQ8Auw31qgZZU47ZjHUhEODef8iN5x8uygAL4ts77ne7pSw6Jbb3oIHo/rAyVkFL/OVZvFEwkY5yBtacxcalw==">
# <script type="text/javascript">  var adblock = true; </script>
# <script src="https://cdn.thestar.com.my/Themes/js/cXense/adframe.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/cXense/PaywallBypassBlocker.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://cdn.thestar.com.my/GlobalBar/global-bar.min.js?v=20210824"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/bootstrap.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/bookmark.min.js?v=20210708"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/loginstatusV2.js?v=20200420"></script>
# <script src="https://cdn.thestar.com.my/Components/Audio/rangetouch.js"></script>
# <script src="https://cdn.thestar.com.my/Components/Audio/audiov11.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/lazysizes.min.js"></script>
# <script src="/theme_metro/js/script.js?v=20210315"></script>
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PVM4TH" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PVM4TH');</script>
# <script>
# var _comscore = _comscore || [];
# _comscore.push({ c1: "2", c2: "6035691" });
# (function () {
# var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# el.parentNode.insertBefore(s, el);
# })();
# </script>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=6035691&amp;cv=2.0&amp;cj=1">
# </img></noscript>
# <script type="text/javascript">
# setTimeout(function(){var a=document.createElement("script");
# var b=document.getElementsByTagName("script")[0];
# a.src=document.location.protocol+"//script.crazyegg.com/pages/scripts/0012/7021.js?"+Math.floor(new Date().getTime()/3600000);
# a.async=true;a.type="text/javascript";b.parentNode.insertBefore(a,b)}, 1);
# </script>
# <!--For engagement-->
# <script type="text/javascript">$(document).ready(function(){if(checkCookie('engagement_box')!=null){var cookie=jQuery.parseJSON(checkCookie('engagement_box'));var new_cookie={};var old_cookie=[];for(var key in cookie){if(cookie[key].timestamp!=undefined){old_cookie.push({key:key,id:cookie[key].id,a:cookie[key].answer,n:cookie[key].timestamp})}}
# if(old_cookie.length>0){old_cookie.sort(function(x,y){return x.n-y.n});var i=0;for(var key in old_cookie){new_cookie[old_cookie[key].key]={n:i,id:old_cookie[key].id,a:old_cookie[key].a}
# i++}}
# addCookie('engagement_box',JSON.stringify(new_cookie),7)}});function addCookie(name,value,days){var expires="";if(days){var date=new Date();date.setTime(date.getTime()+(days*24*60*60*1000));expires="; expires="+date.toUTCString()}
# document.cookie=name+"="+(value||"")+expires+"; path=/"}
# function checkCookie(name){var nameEQ=name+"=";var ca=document.cookie.split(';');for(var i=0;i<ca.length;i++){var c=ca[i];while(c.charAt(0)==' ')c=c.substring(1,c.length);if(c.indexOf(nameEQ)==0)return c.substring(nameEQ.length,c.length)}
# return null}</script>
# <!-- user dialog tutorial 8/7/2020 -->
# <script src="https://cdn.thestar.com.my/Themes/js/anno.js?v=20201130"></script><link href="https://cdn.thestar.com.my/Themes/css/anno.css" rel="stylesheet" type="text/css"/>
# <script src="https://cdn.thestar.com.my/Themes/js/userTour.min.js?v=20201123" type="text/javascript"></script>
# <!-- end user dialog tutorial 8/7/2020 -->
# <!-- vodus here, removed on 2021/09/29 -->
# <!-- End Footer Script -->
# <!--BEGIN Flyin Pullout PDF-->
# <link href="https://cdn.thestar.com.my/Components/Flyin/flyin.css" rel="stylesheet"><link href="https://fonts.googleapis.com/css?family=Lato:400,900" rel="stylesheet"/><div class="detail" id="widgetbox" style="display:none;"><a class="close" id="widgetBoxCloseButton"><img src="https://cdn.thestar.com.my/Themes/img/times-solid.png" style="width: 12px; height:12px;"/></a><div class="openBox"><div class="flex-container open-box-title"><h3 id="widget-title" style="display: block; font-size: 1.17em; margin-block-start: 1em;margin-block-end: 1em; margin-inline-start: 0px;margin-inline-end: 0px; fontweight: bold;"></h3></div><div class="flex-container" style="margin-bottom:11px;"><div><img class="thumbPull" id="widget_img" style="width: 150px;"/></div><div><p id="widget-desc" style="font-size: 0.875em; color: #4a4a4a !important; font-weight: 400;line-height: 1.37em;padding-left: 12px; margin-bottom: 10px;"></p> </div></div><div class="flex-container"><a class="widget-link" id="widget-link">Download now!</a></div></div><div class="flex-container" id="formbox" style="display: none;"><form action="" id="flyinform" method="post"><p>We would love to keep you posted on the latest promotion. Kindly fill the form below</p><div class="formIn"><div><input class="" id="txtName" name="txtName" placeholder="Name" required="" type="text"/></div><div><input id="email" name="email" placeholder="Email" type="email"/></div><div><input id="phone" maxlength="15" name="phone" pattern="[0-9]{10,}" placeholder="Phone" type="number"/></div></div><div class="validate"></div><input type="submit" value="Submit"/><div class="skip"><a id="widget-skip">Skip</a></div><div class="term"><div>Disclaimer: by clicking the Submit button, it is deemed that you consent to the rules and terms set forth in the <a href="https://www.thestar.com.my/privacy/" target="_blank">Privacy Policy</a> as well as <a href="https://www.thestar.com.my/terms/" target="_blank">Terms and Conditions</a> set forth by this site.</div></div></form></div><div class="thankYouBox thanks" style="display: none;margin-left: 40px;"><div class="flex-container thanksbox"><div class="svg-down"></div><div><h3 style="display: block; font-size: 1.17em; margin-block-end: 1em; margin-inline-start: 0px;margin-inline-end: 0px; fontweight: bold;">Thank you for downloading.</h3></div></div><div class="flex-container"><div><p>We hope you enjoy this feature!</p><span>Didn't work? Try <a class="widget-link2" id="widget-link2">downloading</a> again.</span></div></div></div></div>
# <script src="https://cdn.thestar.com.my/Components/Flyin/Flyin_20210318_1.js" type="text/javascript"></script>
# <!--END Flyin Pullout PDF--> <!--resources common js_includes.blade.php-->
# <!-- theme includes js_includes.blade.php -->
# <!--Po.st for social icons in article page-->
# <script type="text/javascript">
# //Remove po.st social share
# //    (function () {
# //        var s = document.createElement('script');
# //        s.type = 'text/javascript';
# //        s.async = true;
# //        s.src = ('https:' == document.location.protocol ? 'https://s' : 'http://i')
# //          + '.po.st/static/v4/post-widget.js#publisherKey=gbc1mg0m85gf08mf3jlb';
# //        var x = document.getElementsByTagName('script')[0];
# //        x.parentNode.insertBefore(s, x);
# //     })();
# //window.pwidget_config = {
# //    publisherKey: 'wid-47r2u0p7',
# //    defaults: { radius: "circle", buttonColor: "default", buttonBackground: "default", label: "false", size: "24", counter: false, padding: true, view: "auto", shareNewWindow: true, services: { twitter: { via: "staronline" } }, jumboPosition: "first", },
# //    onload: function () {
# //        if (navigator.userAgent.match(/Android/i) || navigator.userAgent.match(/iPhone/i) || navigator.userAgent.match(/iPad/i) || navigator.userAgent.match(/iPod/i) || navigator.userAgent.match(/Windows Phone/i)) {
# //           window.postPlatform.createWidget('.post-Wiz-Custom-Items', { buttons: [{ "id": "facebook" }, { "id": "twitter" }, { "id": "linkedin" }, { "id": "line" }, { "id": "reddit" }, { "id": "whatsapp" }, { "id": "email" }], });
# //        }
# //        else window.postPlatform.createWidget('.post-Wiz-Custom-Items', { buttons: [{ "id": "facebook" }, { "id": "twitter" }, { "id": "linkedin" }, { "id": "line" }, { "id": "reddit" }, { "id": "print" }, { "id": "email" }], });
# //    }
# //};
#
# //Added for ajax load today picture
# $(".slick-next").click(function(){
#     setTimeout(function() {
#       addthis.layers.refresh();
#     }, 1000);
# });
#
# $(".slick-prev").click(function(){
#     setTimeout(function() {
#       addthis.layers.refresh();
#     }, 1000);
# });
# //Added for ajax load today picture
# </script>
# <!-- Cxense script begin -->
# <script type="text/javascript">
#
# var pageType = jQuery('meta[name=pageType]').attr("content");
#
# if(pageType == "article"){
#     var cX = window.cX = window.cX || {}; cX.callQueue = cX.callQueue || [];
#     var cxenseRandom = jQuery('meta[name=cxenseRandom]').attr("content");
#     cX.CCE = cX.CCE || {}; cX.CCE.callQueue = cX.CCE.callQueue || [];
#     cX.callQueue.push(['setRandomId',cxenseRandom]); // server side generated id
#     cX.callQueue.push(['setSiteId', '1145278932220698298']);
#
#
#             cX.callQueue.push(['setCustomParameters', { 'usergroup': 'anonymous' }]);
#
#     cX.CCE.callQueue.push(['sendPageViewEvent','smg', '0240b44ae7cc929b3991ca5c126d42a11e5582d4']);
# }
# else{
#     var cX = cX || {}; cX.callQueue = cX.callQueue || [];
#     cX.callQueue.push(['setSiteId', '1145278932220698298']);
#     cX.callQueue.push(['sendPageViewEvent']);
# }
# </script>
# <!-- Cxense script end -->
# <!-- NetCore -->
# <script src="//tw.netcore.co.in/smartechclient.js"></script>
# <script>
#   smartech('create', 'ADGMOT35CHFLVDHBJNIG50K968P0V61ULQ6VTDV1B4AH6RHKPIVG');
#   smartech('register', '1ea761fa10f93f18df46ddc3b4f7b01a');
#   smartech('identify', '');
#   smartech('dispatch',1,{});
# </script>
# <!-- End NetCore -->
# <!-- Widget JS links -->
# <script src="/theme_metro/widgets/article-details/article-details.min.js" type="text/javascript"></script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam-cell.nr-data.net","licenseKey":"ef8b08f3e1","applicationID":"379274163","transactionName":"ZwdaMkpTW0AEWhYKDl5NeQVMW1pdSngSEz14FkwWZHFaXRFLDQ8NVRBLOnlAQVoGVQcgDl4WSglUXlBBJVAMBwRI","queueTime":0,"applicationTime":1998,"atts":"S0BZRAJJSE4=","errorBeacon":"bam-cell.nr-data.net","agent":""}</script></link></input></body>
# </html>

# %% [markdown]
# **No**
#
# Content of the webpage is loaded into soup

# %% [markdown]
# **Try Selenium**
#
# Let's try using Selenium instead of Requests

# %%
# import requests
import time
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Chrome('chromedriver')

url='https://www.thestar.com.my/news/nation/2020/03/23/covid-19-current-situation-in-malaysia-updated-daily'

webpage = driver.get(url)

time.sleep(1)

# load webpage into webdriver




# will not work, cause data not on this server anyway
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-dc8adca2088c> in <module>
#      13
#      14 # load webpage into webdriver
# ---> 15 soup = BeautifulSoup(webpage.page_source, 'html.parser')
#      16
#      17 soup_div = soup.find_all('div',attrs={'id':'table-container'})
#
# AttributeError: 'NoneType' object has no attribute 'page_source'

# %% [markdown]
# ## Check HTML code of the Web page again
#
# <img src='./Images/flourish3.png'>
#
# Notice that there is an iFrame Tag highlighted above?
#
# The actual location of the source web page is embeded within the iframe of theStar
#
# <img src='./Images/flourish4.png'>
#
# Change the URL to the actual source.

# %%
import requests
from bs4 import BeautifulSoup

url='https://public.flourish.studio/visualisation/1641110/embed?auto=1'

# get the data


# load data into bs4



# get data simply by looking for each a links
# Out:
# []

# %%
# soup.find_all('div')
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <base target="_blank"/>
# <link href="https://flo.uri.sh/template/1065/v24/static/style.css" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro:400,700" rel="stylesheet" type="text/css"/>
# <title>COVID-19 MALAYSIA TABLE</title></head>
# <body>
# <style id="cell-styling"></style>
# <script>window.Flourish = {"static_prefix":"https://flo.uri.sh/template/1065/v24/static","environment":"live"};</script><script>var template=function(t){"use strict";var s={},f={table_min_width:300,table_border_color:"#aaaaaa",table_border_width:0,sorting:{enabled:!0,order:"ascending",column_index:null},reloader:{},color:{custom_palette:"Clinton:#1d6996\nTrump:#cc503e"},popup:{font_size:"1rem"},bar_columns:{enabled:!0,type:"bars",bar_1_columns:"Clinton\nTrump",bar_1_column_name:"Vote share",bar_1_max_enabled:!1,bar_1_max:1,bar_1_width:100,bar_1_column_padding:1},line_columns:{enabled:!0,line_1_columns:"1960\n1970\n1980\n1990\n2000\n2010",line_1_column_name:"Population",line_1_min_enabled:!1,line_1_max_enabled:!1,line_1_min:0,line_1_max:1,line_1_width:100,line_1_color:"#1C6996",line_1_area:!0},column_width_mode:"auto",column_widths:"20%, 10%, 50px",cell_fill_direction:"horizontal",cell_height:20,cell_image_height:100,cell_image_radius:0,cell_fill_1:"#ffffff",cell_fill_2:"#ffffff",cell_fill_custom:"",cell_padding_vertical:10,cell_padding_horizontal:5,cell_vertical_alignment:"middle",cell_horizontal_alignment:"left",cell_border_color:"#dddddd",cell_border_style:"solid",cell_border_width:1,cell_font_size:1,cell_font_size_custom:2,cell_font_color:"#333333",cell_link_color:"#4D97C6",cell_wrap:!0,header_font_default:!0,header_font_weight:"bold",header_font_size:1,header_font_color:"#333333",header_horizontal_alignment:"left",header_border_default:!0,header_border_color:"#333333",header_border_style:"solid",header_border_width:2,header_style_default:!0,header_height:30,header_fill:"#ffffff",header_padding:5,search_val:"",search_enabled:!0,search_placeholder:"Search...",search_columns:"all",search_columns_custom:"",search_resize:!1,search_hide_table:!1,search_width:10,pagination_page:0,pagination_amount:10,no_results_text:"No results found",markdown_enabled:!0,mobile:{view:!0,breakpoint:400,cell_font_size:1.25,cell_font_size_custom:1.25,pagination_amount:3},layout:{},localization:{},number_format:{},formatted_columns:""},r="http://www.w3.org/1999/xhtml",i={svg:"http://www.w3.org/2000/svg",xhtml:r,xlink:"http://www.w3.org/1999/xlink",xml:"http://www.w3.org/XML/1998/namespace",xmlns:"http://www.w3.org/2000/xmlns/"};function o(t){var e=t+="",n=e.indexOf(":");return 0<=n&&"xmlns"!==(e=t.slice(0,n))&&(t=t.slice(n+1)),i.hasOwnProperty(e)?{space:i[e],local:t}:t}function a(t){var e=o(t);return(e.local?function(t){return function(){return this.ownerDocument.createElementNS(t.space,t.local)}}:function(n){return function(){var t=this.ownerDocument,e=this.namespaceURI;return e===r&&t.documentElement.namespaceURI===r?t.createElement(n):t.createElementNS(e,n)}})(e)}function e(){}function h(t){return null==t?e:function(){return this.querySelector(t)}}function c(){return[]}function n(t){return new Array(t.length)}function d(t,e){this.ownerDocument=t.ownerDocument,this.namespaceURI=t.namespaceURI,this._next=null,this._parent=t,this.__data__=e}d.prototype={constructor:d,appendChild:function(t){return this._parent.insertBefore(t,this._next)},insertBefore:function(t,e){return this._parent.insertBefore(t,e)},querySelector:function(t){return this._parent.querySelector(t)},querySelectorAll:function(t){return this._parent.querySelectorAll(t)}};var g="$";function x(t,e,n,r,i,o){for(var a,s=0,l=e.length,u=o.length;s<u;++s)(a=e[s])?(a.__data__=o[s],r[s]=a):n[s]=new d(t,o[s]);for(;s<l;++s)(a=e[s])&&(i[s]=a)}function w(t,e,n,r,i,o,a){var s,l,u,c={},h=e.length,p=o.length,f=new Array(h);for(s=0;s<h;++s)(l=e[s])&&(f[s]=u=g+a.call(l,l.__data__,s,e),u in c?i[s]=l:c[u]=l);for(s=0;s<p;++s)(l=c[u=g+a.call(t,o[s],s,o)])?((r[s]=l).__data__=o[s],c[u]=null):n[s]=new d(t,o[s]);for(s=0;s<h;++s)(l=e[s])&&c[f[s]]===l&&(i[s]=l)}function p(t,e){return t<e?-1:e<t?1:e<=t?0:NaN}function l(t){return t.ownerDocument&&t.ownerDocument.defaultView||t.document&&t||t.defaultView}function u(t){return t.trim().split(/^|\s+/)}function _(t){return t.classList||new m(t)}function m(t){this._node=t ...
# //# sourceMappingURL=template.js.map
# </script><script>
# var path = document.location.href.match(/\/visualisation\/(\d+)/);
# if (path) {
# 	path = path[0];
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# 	ga("create", "UA-44635456-19", "auto", { storage: "none" });
# 	ga("set", "transport", "beacon");
# 	ga("set", "dimension1", path.substr(1));
# 	ga("set", "dimension2", new Date().toISOString());
# 	ga("send", "pageview", path);
# }</script><script src="https://public.flourish.studio/resources/v3/embedded.js"></script><script>
# 		function _Flourish_unflattenInto(dest, src) {
# 			dest = dest || {};
# 			for (var k in src) {
# 				var t = dest;
# 				for (var i = k.indexOf("."), p = 0; i >= 0; i = k.indexOf(".", p = i+1)) {
# 					var s = k.substring(p, i);
# 					if (!(s in t)) t[s] = {};
# 					t = t[s];
# 				}
# 				t[k.substring(p)] = src[k];
# 			}
# 			return dest;
# 		}
# 		var _Flourish_settings = {"cell_font_size":"custom","cell_font_size_custom":1.1,"cell_padding_vertical":0,"cell_wrap":true,"column_width_mode":"fixed","column_widths":"7%, 7%, 7%,7%,10%","layout.background_color":"#ffffff","layout.color":"#000000","layout.logo_url":"https://public.flourish.studio/uploads/384e93f7-2c24-4186-ad92-b5c5a3351527.jpg","layout.multiple_sources":true,"layout.note":"","layout.size":15,"layout.source_name":"Health Ministry ","layout.source_name_2":"","layout.subtitle":"As at 5.19pm, April 22, 2021","layout.subtitle_styling":true,"layout.text":"The list below is arranged in groups of 7. To see more dates, press the \">\" button located below the table","layout.text_styling":false,"layout.title":"Malaysia: 384,688 cases, 1,407 deaths, 361,267 recovered","layout.title_color":"#ff0000","layout.title_size":"2","layout.title_styling":true,"mobile.pagination_amount":7,"mobile.view":false,"pagination_amount":7,"search_enabled":false,"search_hide_table":false,"table_min_width":300};
# 		_Flourish_unflattenInto(window.template.state, _Flourish_settings);
#
# 		var _Flourish_data_column_names = {"rows":{"columns":["Date","Total cases","New cases","Total deaths","Total recovered"]}},
# 		    _Flourish_data_metadata = {"rows":{"columns":[null,null,null,null,null]}},
# 		    _Flourish_data = {"rows":[{"columns":["22-Apr-21","384,688","2,875","1407","361,267"]},{"columns":["21-Apr-21","381,813","2,340","1400","358,726"]},{"columns":["20-Apr-21","379,473","2,341","1389","356,816"]},{"columns":["19-Apr-21","377,132","2,078","1386","355,224"]},{"columns":["18-Apr-21","375,054","2,195","1378","353,822"]},{"columns":["17-Apr-21","372,859","2,331","1370","352,395"]},{"columns":["16-Apr-21","370,528","2,551","1365","350,563"]},{"columns":["15-Apr-21","367,977","2,148","1363","349,039"]},{"columns":["14-Apr-21","365,829","1,889","1353","347,780"]},{"columns":["13-Apr-21","363,940","1,767","1345","346,295"]},{"columns":["12-Apr-21","362,173","1,317","1333","345,005"]},{"columns":["11-Apr-21","360,856","1,739","1329","343,953"]},{"columns":["10-Apr-21","359,117","1,510","1321","342,737"]},{"columns":["9-Apr-21","357,607","1,854","1313","341,489"]},{"columns":["8-Apr-21","355,753","1,285","1308","340,242"]},{"columns":["7-Apr-21","354,468","1,139","1304","339,067"]},{"columns":["6-Apr-21","353,329","1,300","1300","337,868"]},{"columns":["5-Apr-21","352,029","1,070","1295","336,456"]},{"columns":["4-Apr-21","350,959","1,349","1288","335,162"]},{"columns":["3-Apr-21","349,610","1,638","1286","333,892"]},{"columns":["2-Apr-21","347,972","1,294","1283","332,443"]},{"columns":["1-Apr-21","346,678","1,178","1278","331,001"]},{"columns":["31-Mar-21","345,500","1,482","1272","329,624"]},{"columns":["30-Mar-21","344,018","1,133","1265","328,554"]},{"columns":["29-Mar-21","342,885","941","1260","327,406"]},{"columns":["28-Mar-21","341,944","1,302","1255","326,309"]},{"columns":["27-Mar-21","340,642","1,199","1251","325,182"]},{"columns":["26-Mar-21","339,443","1,275","1249","323,925"]},{"columns":["25-Mar-21","338,168","1,360","1248","322,416"]},{"columns":["24-Mar-21","336,808","1,268","1246","320,925"]},{"columns":["23-Mar-21","335,540","1,384","1244","319,842"]},{"columns":["22-Mar-21","334,156","1,116","1238","318,784"]},{"columns":["21-Mar-21","333,040","1,327","1233","317,289"]},{"columns":["20-Mar-21","331,713","1,671","1229","316,042"]},{"columns":["19-Mar-21","330,042","1,576","1225","314,457"]},{"columns":["18-Mar-21","328,466","1,213","1223","312,461"]},{"columns":["17-Mar-21","327,253","1,219","1220","310,958"]},{"columns":["16-Mar-21","326,034","1,063","1218","309,612"]},{"columns":["15-Mar-21","324,971","1,208","1213","308,247"]},{"columns":["14-Mar-21","323,763","1,354","1210","306,274"]},{"columns":["13-Mar-21","322,409","1,470","1206","304,492"]},{"columns":["12-Mar-21","320,939","1,575","1203","302,662"]},{"columns":["11-Mar-21","319,364","1,647","1200","300,620"]},{"columns":["10-Mar-21","317,717","1,448","1191","298,516"]},{"columns":["9-Mar-21","316,269","1,280","1186","296,379"]},{"columns":["8-Mar-21","314,989","1,529","1177","294,034"]},{"columns":["7-Mar-21","313,460","1,683","1169","291,958"]},{"columns":["6-Mar-21","311,777","1,680","1166","289,452"]},{"columns":["5-Mar-21","310,097","2154","1159","286,904"]},{"columns":["4-Mar-21","307,943","2,063","1153","283,629"]},{"columns":["3-Mar-21","305,880","1,745","1148","280,707"]},{"columns":["2-Mar-21","304,135","1,555","1141","278,431"]},{"columns":["1-Mar-21","302,580","1,828","1135","275,903"]},{"columns":["28-Feb-21","300,752","2,437","1130","273,417"]},{"columns":["27-Feb-21","298,315","2,364","1121","270,166"]},{"columns":["26-Feb-21","295,951","2,253","1111","266,846"]},{"columns":["25-Feb-21","293,698","1,924","1100","263,761"]},{"columns":["24-Feb-21","291,774","3,545","1088","260,009"]},{"columns":["23-Feb-21","288,229","2,468","1076","256,678"]},{"columns":["22-Feb-21","285,761","2,192","1062","252,623"]},{"columns":["21-Feb-21","283,569","3,297","1056","249,209"]},{"columns":["20-Feb-21","280,272","2,461","1051","244,753"]},{"columns":["19-Feb-21","277,811","2,936","1043","239,971"]},{"columns":["18-Feb-21","274,875","2,712","1030","235,082"]},{"columns":["17-Feb-21","272,163","2,998","1005","229,762"]},{"columns":["16-Feb-21", ...
# 		for (var _Flourish_dataset in _Flourish_data) {
# 				window.template.data[_Flourish_dataset] = _Flourish_data[_Flourish_dataset];
# 				window.template.data[_Flourish_dataset].column_names = _Flourish_data_column_names[_Flourish_dataset];
# 				window.template.data[_Flourish_dataset].metadata = _Flourish_data_metadata[_Flourish_dataset];
# 		}
# 		window.template.draw();
# 	</script></body></html>>

# %% [markdown]
# ### Cannot Use BeautifulSoup
#
# <img src='./Images/flourish.png'>
#
# Check the Javascript found above.
#
# The data for the table is within the Javascript coding.
#
# **2 options.**
#
# **Option 1.** Try to Scrape the Javascript. Not that possible, unless fully understand how the Javascript program going to output the HTML to the Web Page.
#
# **Option 2.** Use Selenium Webdriver to run the Javascript within the webdriver and then scrape the HTML output.

# %%
# Use Selenium 
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Chrome('chromedriver')

url='https://public.flourish.studio/visualisation/1641110/embed?auto=1'

# get the data


# load data into bs4



# get data simply by looking for each a links
# Out:
# ['22-Apr-21\n384688\n2875\n1407\n361267\n',
#  '21-Apr-21\n381813\n2340\n1400\n358726\n',
#  '20-Apr-21\n379473\n2341\n1389\n356816\n',
#  '19-Apr-21\n377132\n2078\n1386\n355224\n',
#  '18-Apr-21\n375054\n2195\n1378\n353822\n',
#  '17-Apr-21\n372859\n2331\n1370\n352395\n',
#  '16-Apr-21\n370528\n2551\n1365\n350563\n']

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Chrome('chromedriver')

url='https://public.flourish.studio/visualisation/1641110/embed?auto=1'

# get the data


# load data into bs4



# get data simply by looking for each a links
# Out:
# ['Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '22-Apr-21\n',
#  '384688\n',
#  '2875\n',
#  '1407\n',
#  '361267\n',
#  '21-Apr-21\n',
#  '381813\n',
#  '2340\n',
#  '1400\n',
#  '358726\n',
#  '20-Apr-21\n',
#  '379473\n',
#  '2341\n',
#  '1389\n',
#  '356816\n',
#  '19-Apr-21\n',
#  '377132\n',
#  '2078\n',
#  '1386\n',
#  '355224\n',
#  '18-Apr-21\n',
#  '375054\n',
#  '2195\n',
#  '1378\n',
#  '353822\n',
#  '17-Apr-21\n',
#  '372859\n',
#  '2331\n',
#  '1370\n',
#  '352395\n',
#  '16-Apr-21\n',
#  '370528\n',
#  '2551\n',
#  '1365\n',
#  '350563\n',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '22-Apr-21\n',
#  '384688\n',
#  '2875\n',
#  '1407\n',
#  '361267\n',
#  '21-Apr-21\n',
#  '381813\n',
#  '2340\n',
#  '1400\n',
#  '358726\n',
#  '20-Apr-21\n',
#  '379473\n',
#  '2341\n',
#  '1389\n',
#  '356816\n',
#  '19-Apr-21\n',
#  '377132\n',
#  '2078\n',
#  '1386\n',
#  '355224\n',
#  '18-Apr-21\n',
#  '375054\n',
#  '2195\n',
#  '1378\n',
#  '353822\n',
#  '17-Apr-21\n',
#  '372859\n',
#  '2331\n',
#  '1370\n',
#  '352395\n',
#  '16-Apr-21\n',
#  '370528\n',
#  '2551\n',
#  '1365\n',
#  '350563\n',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '22-Apr-21\n',
#  '384688\n',
#  '2875\n',
#  '1407\n',
#  '361267\n',
#  '21-Apr-21\n',
#  '381813\n',
#  '2340\n',
#  '1400\n',
#  '358726\n',
#  '20-Apr-21\n',
#  '379473\n',
#  '2341\n',
#  '1389\n',
#  '356816\n',
#  '19-Apr-21\n',
#  '377132\n',
#  '2078\n',
#  '1386\n',
#  '355224\n',
#  '18-Apr-21\n',
#  '375054\n',
#  '2195\n',
#  '1378\n',
#  '353822\n',
#  '17-Apr-21\n',
#  '372859\n',
#  '2331\n',
#  '1370\n',
#  '352395\n',
#  '16-Apr-21\n',
#  '370528\n',
#  '2551\n',
#  '1365\n',
#  '350563\n',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '22-Apr-21\n',
#  '384688\n',
#  '2875\n',
#  '1407\n',
#  '361267\n',
#  '21-Apr-21\n',
#  '381813\n',
#  '2340\n',
#  '1400\n',
#  '358726\n',
#  '20-Apr-21\n',
#  '379473\n',
#  '2341\n',
#  '1389\n',
#  '356816\n',
#  '19-Apr-21\n',
#  '377132\n',
#  '2078\n',
#  '1386\n',
#  '355224\n',
#  '18-Apr-21\n',
#  '375054\n',
#  '2195\n',
#  '1378\n',
#  '353822\n',
#  '17-Apr-21\n',
#  '372859\n',
#  '2331\n',
#  '1370\n',
#  '352395\n',
#  '16-Apr-21\n',
#  '370528\n',
#  '2551\n',
#  '1365\n',
#  '350563\n',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '22-Apr-21\n',
#  '384688\n',
#  '2875\n',
#  '1407\n',
#  '361267\n',
#  '21-Apr-21\n',
#  '381813\n',
#  '2340\n',
#  '1400\n',
#  '358726\n',
#  '20-Apr-21\n',
#  '379473\n',
#  '2341\n',
#  '1389\n',
#  '356816\n',
#  '19-Apr-21\n',
#  '377132\n',
#  '2078\n',
#  '1386\n',
#  '355224\n',
#  '18-Apr-21\n',
#  '375054\n',
#  '2195\n',
#  '1378\n',
#  '353822\n',
#  '17-Apr-21\n',
#  '372859\n',
#  '2331\n',
#  '1370\n',
#  '352395\n',
#  '16-Apr-21\n',
#  '370528\n',
#  '2551\n',
#  '1365\n',
#  '350563\n',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '22-Apr-21\n',
#  '384688\n',
#  '2875\n',
#  '1407\n',
#  '361267\n',
#  '21-Apr-21\n',
#  '381813\n',
#  '2340\n',
#  '1400\n',
#  '358726\n',
#  '20-Apr-21\n',
#  '379473\n',
#  '2341\n',
#  '1389\n',
#  '356816\n',
#  '19-Apr-21\n',
#  '377132\n',
#  '2078\n',
#  '1386\n',
#  '355224\n',
#  '18-Apr-21\n',
#  '375054\n',
#  '2195\n',
#  '1378\n',
#  '353822\n',
#  '17-Apr-21\n',
#  '372859\n',
#  '2331\n',
#  '1370\n',
#  '352395\n',
#  '16-Apr-21\n',
#  '370528\n',
#  '2551\n',
#  '1365\n',
#  '350563\n',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '22-Apr-21\n',
#  '384688\n',
#  '2875\n',
#  '1407\n',
#  '361267\n',
#  '21-Apr-21\n',
#  '381813\n',
#  '2340\n',
#  '1400\n',
#  '358726\n',
#  '20-Apr-21\n',
#  '379473\n',
#  '2341\n',
#  '1389\n',
#  '356816\n',
#  '19-Apr-21\n',
#  '377132\n',
#  '2078\n',
#  '1386\n',
#  '355224\n',
#  '18-Apr-21\n',
#  '375054\n',
#  '2195\n',
#  '1378\n',
#  '353822\n',
#  '17-Apr-21\n',
#  '372859\n',
#  '2331\n',
#  '1370\n',
#  '352395\n',
#  '16-Apr-21\n',
#  '370528\n',
#  '2551\n',
#  '1365\n',
#  '350563\n']

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Chrome('chromedriver')

url='https://public.flourish.studio/visualisation/1641110/embed?auto=1'

# get the data


# load data into bs4


# get data simply by looking for each a links
# Out:
# ['Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '22-Apr-21',
#  '384688',
#  '2875',
#  '1407',
#  '361267',
#  '21-Apr-21',
#  '381813',
#  '2340',
#  '1400',
#  '358726',
#  '20-Apr-21',
#  '379473',
#  '2341',
#  '1389',
#  '356816',
#  '19-Apr-21',
#  '377132',
#  '2078',
#  '1386',
#  '355224',
#  '18-Apr-21',
#  '375054',
#  '2195',
#  '1378',
#  '353822',
#  '17-Apr-21',
#  '372859',
#  '2331',
#  '1370',
#  '352395',
#  '16-Apr-21',
#  '370528',
#  '2551',
#  '1365',
#  '350563',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '22-Apr-21',
#  '384688',
#  '2875',
#  '1407',
#  '361267',
#  '21-Apr-21',
#  '381813',
#  '2340',
#  '1400',
#  '358726',
#  '20-Apr-21',
#  '379473',
#  '2341',
#  '1389',
#  '356816',
#  '19-Apr-21',
#  '377132',
#  '2078',
#  '1386',
#  '355224',
#  '18-Apr-21',
#  '375054',
#  '2195',
#  '1378',
#  '353822',
#  '17-Apr-21',
#  '372859',
#  '2331',
#  '1370',
#  '352395',
#  '16-Apr-21',
#  '370528',
#  '2551',
#  '1365',
#  '350563',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '22-Apr-21',
#  '384688',
#  '2875',
#  '1407',
#  '361267',
#  '21-Apr-21',
#  '381813',
#  '2340',
#  '1400',
#  '358726',
#  '20-Apr-21',
#  '379473',
#  '2341',
#  '1389',
#  '356816',
#  '19-Apr-21',
#  '377132',
#  '2078',
#  '1386',
#  '355224',
#  '18-Apr-21',
#  '375054',
#  '2195',
#  '1378',
#  '353822',
#  '17-Apr-21',
#  '372859',
#  '2331',
#  '1370',
#  '352395',
#  '16-Apr-21',
#  '370528',
#  '2551',
#  '1365',
#  '350563',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '22-Apr-21',
#  '384688',
#  '2875',
#  '1407',
#  '361267',
#  '21-Apr-21',
#  '381813',
#  '2340',
#  '1400',
#  '358726',
#  '20-Apr-21',
#  '379473',
#  '2341',
#  '1389',
#  '356816',
#  '19-Apr-21',
#  '377132',
#  '2078',
#  '1386',
#  '355224',
#  '18-Apr-21',
#  '375054',
#  '2195',
#  '1378',
#  '353822',
#  '17-Apr-21',
#  '372859',
#  '2331',
#  '1370',
#  '352395',
#  '16-Apr-21',
#  '370528',
#  '2551',
#  '1365',
#  '350563',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '22-Apr-21',
#  '384688',
#  '2875',
#  '1407',
#  '361267',
#  '21-Apr-21',
#  '381813',
#  '2340',
#  '1400',
#  '358726',
#  '20-Apr-21',
#  '379473',
#  '2341',
#  '1389',
#  '356816',
#  '19-Apr-21',
#  '377132',
#  '2078',
#  '1386',
#  '355224',
#  '18-Apr-21',
#  '375054',
#  '2195',
#  '1378',
#  '353822',
#  '17-Apr-21',
#  '372859',
#  '2331',
#  '1370',
#  '352395',
#  '16-Apr-21',
#  '370528',
#  '2551',
#  '1365',
#  '350563',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '22-Apr-21',
#  '384688',
#  '2875',
#  '1407',
#  '361267',
#  '21-Apr-21',
#  '381813',
#  '2340',
#  '1400',
#  '358726',
#  '20-Apr-21',
#  '379473',
#  '2341',
#  '1389',
#  '356816',
#  '19-Apr-21',
#  '377132',
#  '2078',
#  '1386',
#  '355224',
#  '18-Apr-21',
#  '375054',
#  '2195',
#  '1378',
#  '353822',
#  '17-Apr-21',
#  '372859',
#  '2331',
#  '1370',
#  '352395',
#  '16-Apr-21',
#  '370528',
#  '2551',
#  '1365',
#  '350563',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '22-Apr-21',
#  '384688',
#  '2875',
#  '1407',
#  '361267',
#  '21-Apr-21',
#  '381813',
#  '2340',
#  '1400',
#  '358726',
#  '20-Apr-21',
#  '379473',
#  '2341',
#  '1389',
#  '356816',
#  '19-Apr-21',
#  '377132',
#  '2078',
#  '1386',
#  '355224',
#  '18-Apr-21',
#  '375054',
#  '2195',
#  '1378',
#  '353822',
#  '17-Apr-21',
#  '372859',
#  '2331',
#  '1370',
#  '352395',
#  '16-Apr-21',
#  '370528',
#  '2551',
#  '1365',
#  '350563']

# %%
# Next Page

driver.find_element_by_xpath('/html/body/main/section[4]/div[1]/div/div[4]/button[2]').click()

soup = BeautifulSoup(driver.page_source,'html.parser')

data=[]
# get data simply by looking for each a links


# depends
# if first time scrape, must scrape all previous pages. then paginate and get those data
# if only need to get the latest everyday, then no need to grab the same data all over again

# look at this class="pagination-total"
# Out:
# ['Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '15-Apr-21\n',
#  '367977\n',
#  '2148\n',
#  '1363\n',
#  '349039\n',
#  '14-Apr-21\n',
#  '365829\n',
#  '1889\n',
#  '1353\n',
#  '347780\n',
#  '13-Apr-21\n',
#  '363940\n',
#  '1767\n',
#  '1345\n',
#  '346295\n',
#  '12-Apr-21\n',
#  '362173\n',
#  '1317\n',
#  '1333\n',
#  '345005\n',
#  '11-Apr-21\n',
#  '360856\n',
#  '1739\n',
#  '1329\n',
#  '343953\n',
#  '10-Apr-21\n',
#  '359117\n',
#  '1510\n',
#  '1321\n',
#  '342737\n',
#  '9-Apr-21\n',
#  '357607\n',
#  '1854\n',
#  '1313\n',
#  '341489\n',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '15-Apr-21\n',
#  '367977\n',
#  '2148\n',
#  '1363\n',
#  '349039\n',
#  '14-Apr-21\n',
#  '365829\n',
#  '1889\n',
#  '1353\n',
#  '347780\n',
#  '13-Apr-21\n',
#  '363940\n',
#  '1767\n',
#  '1345\n',
#  '346295\n',
#  '12-Apr-21\n',
#  '362173\n',
#  '1317\n',
#  '1333\n',
#  '345005\n',
#  '11-Apr-21\n',
#  '360856\n',
#  '1739\n',
#  '1329\n',
#  '343953\n',
#  '10-Apr-21\n',
#  '359117\n',
#  '1510\n',
#  '1321\n',
#  '342737\n',
#  '9-Apr-21\n',
#  '357607\n',
#  '1854\n',
#  '1313\n',
#  '341489\n',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '15-Apr-21\n',
#  '367977\n',
#  '2148\n',
#  '1363\n',
#  '349039\n',
#  '14-Apr-21\n',
#  '365829\n',
#  '1889\n',
#  '1353\n',
#  '347780\n',
#  '13-Apr-21\n',
#  '363940\n',
#  '1767\n',
#  '1345\n',
#  '346295\n',
#  '12-Apr-21\n',
#  '362173\n',
#  '1317\n',
#  '1333\n',
#  '345005\n',
#  '11-Apr-21\n',
#  '360856\n',
#  '1739\n',
#  '1329\n',
#  '343953\n',
#  '10-Apr-21\n',
#  '359117\n',
#  '1510\n',
#  '1321\n',
#  '342737\n',
#  '9-Apr-21\n',
#  '357607\n',
#  '1854\n',
#  '1313\n',
#  '341489\n',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '15-Apr-21\n',
#  '367977\n',
#  '2148\n',
#  '1363\n',
#  '349039\n',
#  '14-Apr-21\n',
#  '365829\n',
#  '1889\n',
#  '1353\n',
#  '347780\n',
#  '13-Apr-21\n',
#  '363940\n',
#  '1767\n',
#  '1345\n',
#  '346295\n',
#  '12-Apr-21\n',
#  '362173\n',
#  '1317\n',
#  '1333\n',
#  '345005\n',
#  '11-Apr-21\n',
#  '360856\n',
#  '1739\n',
#  '1329\n',
#  '343953\n',
#  '10-Apr-21\n',
#  '359117\n',
#  '1510\n',
#  '1321\n',
#  '342737\n',
#  '9-Apr-21\n',
#  '357607\n',
#  '1854\n',
#  '1313\n',
#  '341489\n',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '15-Apr-21\n',
#  '367977\n',
#  '2148\n',
#  '1363\n',
#  '349039\n',
#  '14-Apr-21\n',
#  '365829\n',
#  '1889\n',
#  '1353\n',
#  '347780\n',
#  '13-Apr-21\n',
#  '363940\n',
#  '1767\n',
#  '1345\n',
#  '346295\n',
#  '12-Apr-21\n',
#  '362173\n',
#  '1317\n',
#  '1333\n',
#  '345005\n',
#  '11-Apr-21\n',
#  '360856\n',
#  '1739\n',
#  '1329\n',
#  '343953\n',
#  '10-Apr-21\n',
#  '359117\n',
#  '1510\n',
#  '1321\n',
#  '342737\n',
#  '9-Apr-21\n',
#  '357607\n',
#  '1854\n',
#  '1313\n',
#  '341489\n',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '15-Apr-21\n',
#  '367977\n',
#  '2148\n',
#  '1363\n',
#  '349039\n',
#  '14-Apr-21\n',
#  '365829\n',
#  '1889\n',
#  '1353\n',
#  '347780\n',
#  '13-Apr-21\n',
#  '363940\n',
#  '1767\n',
#  '1345\n',
#  '346295\n',
#  '12-Apr-21\n',
#  '362173\n',
#  '1317\n',
#  '1333\n',
#  '345005\n',
#  '11-Apr-21\n',
#  '360856\n',
#  '1739\n',
#  '1329\n',
#  '343953\n',
#  '10-Apr-21\n',
#  '359117\n',
#  '1510\n',
#  '1321\n',
#  '342737\n',
#  '9-Apr-21\n',
#  '357607\n',
#  '1854\n',
#  '1313\n',
#  '341489\n',
#  'Date',
#  'Total cases',
#  'New cases',
#  'Total deaths',
#  'Total recovered',
#  '15-Apr-21\n',
#  '367977\n',
#  '2148\n',
#  '1363\n',
#  '349039\n',
#  '14-Apr-21\n',
#  '365829\n',
#  '1889\n',
#  '1353\n',
#  '347780\n',
#  '13-Apr-21\n',
#  '363940\n',
#  '1767\n',
#  '1345\n',
#  '346295\n',
#  '12-Apr-21\n',
#  '362173\n',
#  '1317\n',
#  '1333\n',
#  '345005\n',
#  '11-Apr-21\n',
#  '360856\n',
#  '1739\n',
#  '1329\n',
#  '343953\n',
#  '10-Apr-21\n',
#  '359117\n',
#  '1510\n',
#  '1321\n',
#  '342737\n',
#  '9-Apr-21\n',
#  '357607\n',
#  '1854\n',
#  '1313\n',
#  '341489\n']

# %% [markdown]
# ### Footnote:
#
# HTML iframe tag
#
# **Specification:**
#
# https://www.w3.org/html/wg/spec/the-iframe-element.html
